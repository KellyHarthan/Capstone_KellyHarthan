# %% [markdown]
# # PERMISSIONS AUTHORIZATION

# %%
import requests
import pandas as pd

# %%
CLIENT_ID = 'c7d16c8600ab433ea5aede2202285c1e'
CLIENT_SECRET = '69b7f20b150845a1ae6427a66f14d780'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
#needs to be updated every hour
headers = {
    'Authorization': 'Bearer BQAlVnemLaeHsWsztFH5TMWJ8Bvmgzf175Kts23DSFDcMuYNgjxEtfpnViAJUCv06aviIGZ-vJEeTNk3-55cELa1DaQVFPQ9EXe4_pqykzBh1XQhd5a8nQnkeCL9OY--yBKYPSOSnG1V3Pt0D4ab-_PKqdPgzT9DQFTCjmG4IgvvyeUT7v1OlcsspKv1pJt11KI'.format(token=access_token)
}

# %% [markdown]
# # PULLING IN BILLBOARD 1982

# %%
BB_1982_URL="https://api.spotify.com/v1/playlists/1bk6tO6d5oes6n0vhACi5x"
res1982=requests.get(BB_1982_URL, headers=headers)  
res1982
# Out:
# <Response [401]>

# %%
import spotipy
sp = spotipy.Spotify()
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/embed/playlist/1bk6tO6d5oes6n0vhACi5x?utm_source=generator"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
    for track in sp.playlist_tracks(playlist_URI)["items"]:
        #URI
        track_uri = track["track"]["uri"]

        #Track name
        track_name = track["track"]["name"]

        #Main Artist
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)

        #Name, popularity, genre
        artist_name = track["track"]["artists"][0]["name"]
        
        #artist_pop = artist_info["popularity"]
        artist_genres = artist_info["genres"]

        #Album
        album = track["track"]["album"]["name"]

        #Popularity of the track
        track_pop = track["track"]["popularity"]
        
        #Track Name
        track_name = track["track"]["name"]
        
        #Track URI
        track_uri = track["track"]["uri"]

# %% [markdown]
# # TRACK URI

# %% [markdown]
# def get_playlist_uri(playlist_link):
#     return playlist_link.split("/")[-1].split("?")[0]
#
#
# def get_tracks():
#     tracks = []
#     playlist_uri = get_playlist_uri(playlist_link)
#     for track in sp.playlist_tracks(playlist_uri)["items"]:
#         track_uri = track["track"]["uri"]
#         track_name = track["track"]["name"]
#         result = track_uri#, sp.audio_features(track_uri)
#         tracks.append(result)
#
#     return tracks
#
#
# track_uri = get_tracks()

# %% [markdown]
# t_uri=pd.DataFrame(track_uri)
# t_uri=t_uri.rename(columns={0:'track_uri'})
# t_uri=t_uri['track_uri'].str.lstrip('spotify:track:')
# t_uri=pd.DataFrame(t_uri)
# t_uri

# %% [markdown]
# # ARTIST NAME

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        artist_name = track["track"]["artists"][0]["name"]
        result = artist_name
        tracks.append(result)

    return tracks


artist_name = get_tracks()

# %%
a_name=pd.DataFrame(artist_name).reset_index()
a_name=a_name.rename(columns={0:'artist_name'})
a_name['year']=1982

# %% [markdown]
# # TRACK NAME

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_name = track["track"]["name"]
        result = track_name#, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


track_name = get_tracks()

# %%
t_name=pd.DataFrame(track_name).reset_index()
t_name=t_name.rename(columns={0:'track_name'})
t_name
# Out:
#     index                             track_name
# 0       0                               Physical
# 1       1                       Eye of the Tiger
# 2       2                    I Love Rock 'N Roll
# 3       3                        Ebony And Ivory
# 4       4                             Centerfold
# ..    ...                                    ...
# 94     94               Do I Do - Single Version
# 95     95                Working for the Weekend
# 96     96  Arthur's Theme (Best That You Can Do)
# 97     97     Through The Years - Single Version
# 98     98      Edge of Seventeen - 2016 Remaster
#
# [99 rows x 2 columns]

# %% [markdown]
# # AUDIO FEATURES

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_name = track["track"]["name"]
        result = sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


audio = get_tracks()

# %%
audio
# Out:
# [[{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.804,
#    'key': 0,
#    'loudness': -7.299,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.327,
#    'instrumentalness': 5.98e-06,
#    'liveness': 0.0818,
#    'valence': 0.658,
#    'tempo': 111.457,
#    'type': 'audio_features',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L3b6iaVhDVjfo52Hbvh9Z',
#    'duration_ms': 329413,
#    'time_signature': 4}]]

# %%
audio_fea=pd.DataFrame(audio[0])
audio_fea=audio_fea.drop(columns=['type','uri','track_href','analysis_url'])
audio_fea=audio_fea.rename(columns={'id':'track_uri'})
audio_fea
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.591   0.804    0    -7.299     1       0.0454         0.327
#
#    instrumentalness  liveness  valence    tempo               track_uri  \
# 0          0.000006    0.0818    0.658  111.457  7L3b6iaVhDVjfo52Hbvh9Z
#
#    duration_ms  time_signature
# 0       329413               4

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)
        artist_genres = artist_info["genres"]
        result = artist_genres
        tracks.append(result)

    return tracks


track_genres = get_tracks()

# %%
genres=pd.DataFrame(track_genres)
genres=genres.rename(columns={0:'primary_genre',1:'sub_genre_1', 2:'sub_genre_2'})
genres= genres[['primary_genre','sub_genre_1','sub_genre_2']].reset_index()
genres
# Out:
#     index    primary_genre            sub_genre_1    sub_genre_2
# 0       0  adult standards       australian dance  bubblegum pop
# 1       1       album rock              hard rock           rock
# 2       2        glam punk                   rock           None
# 3       3       album rock             beatlesque   classic rock
# 4       4       album rock               art rock     blues rock
# ..    ...              ...                    ...            ...
# 94     94             funk              indie r&b         motown
# 95     95       album rock  classic canadian rock   classic rock
# 96     96  adult standards             album rock          disco
# 97     97  adult standards    classic country pop        country
# 98     98       album rock         heartland rock    mellow gold
#
# [99 rows x 4 columns]

# %%
final_1982_df=a_name.merge(t_name, how='left', on='index')
final_1982_df=final_1982_df.merge(genres, how='left', on='index')
final_1982_df.head(15)
# Out:
#     index                  artist_name  year  \
# 0       0           Olivia Newton-John  1982
# 1       1                     Survivor  1982
# 2       2  Joan Jett & the Blackhearts  1982
# 3       3               Paul McCartney  1982
# 4       4            The J. Geils Band  1982
# 5       5             The Human League  1982
# 6       6              John Mellencamp  1982
# 7       7              John Mellencamp  1982
# 8       8            Steve Miller Band  1982
# 9       9                      Chicago  1982
# 10     10                    Soft Cell  1982
# 11     11                     Vangelis  1982
# 12     12                 Quarterflash  1982
# 13     13                         TOTO  1982
# 14     14      Daryl Hall & John Oates  1982
#
#                                track_name    primary_genre       sub_genre_1  \
# 0                                Physical  adult standards  australian dance
# 1                        Eye of the Tiger       album rock         hard rock
# 2                     I Love Rock 'N Roll        glam punk              rock
# 3                         Ebony And Ivory       album rock        beatlesque
# 4                              Centerfold       album rock          art rock
# 5                       Don't You Want Me         art rock      new romantic
# 6                            Jack & Diane       album rock      classic rock
# 7                           Hurts So Good       album rock      classic rock
# 8                             Abracadabra       album rock        blues rock
# 9   Hard to Say I'm Sorry - 2009 Remaster  adult standards        album rock
# 10                           Tainted Love     new romantic          new wave
# 11                       Chariots Of Fire        cyberpunk           new age
# 12                        Harden My Heart       album rock      new wave pop
# 13                                Rosanna       album rock      classic rock
# 14        I Can't Go for That (No Can Do)       album rock      classic rock
#
#       sub_genre_2
# 0   bubblegum pop
# 1            rock
# 2            None
# 3    classic rock
# 4      blues rock
# 5        new wave
# 6    country rock
# 7    country rock
# 8    classic rock
# 9    classic rock
# 10   new wave pop
# 11    synthesizer
# 12      soft rock
# 13    mellow gold
# 14    mellow gold
