# %% [markdown]
# # PERMISSIONS AUTHORIZATION

# %%
import requests
import pandas as pd
from pandas import DataFrame
import numpy as np
from itertools import chain
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
CLIENT_ID = 'c7d16c8600ab433ea5aede2202285c1e'
CLIENT_SECRET = '69b7f20b150845a1ae6427a66f14d780'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
#needs to be updated every hour
headers = {
    'Authorization': 'Bearer BQAlVnemLaeHsWsztFH5TMWJ8Bvmgzf175Kts23DSFDcMuYNgjxEtfpnViAJUCv06aviIGZ-vJEeTNk3-55cELa1DaQVFPQ9EXe4_pqykzBh1XQhd5a8nQnkeCL9OY--yBKYPSOSnG1V3Pt0D4ab-_PKqdPgzT9DQFTCjmG4IgvvyeUT7v1OlcsspKv1pJt11KI'.format(token=access_token)
}

# %% [markdown]
# # PULLING IN BILLBOARD 1982

# %%
BB_1982_URL="https://api.spotify.com/v1/playlists/1bk6tO6d5oes6n0vhACi5x"
res1982=requests.get(BB_1982_URL, headers=headers)  
res1982
# Out:
# <Response [401]>

# %%
import spotipy
sp = spotipy.Spotify()
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/embed/playlist/1bk6tO6d5oes6n0vhACi5x?utm_source=generator"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
    for track in sp.playlist_tracks(playlist_URI)["items"]:
        #URI
        track_uri = track["track"]["uri"]

        #Track name
        track_name = track["track"]["name"]

        #Main Artist
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)

        #Name, popularity, genre
        artist_name = track["track"]["artists"][0]["name"]
        
        #artist_pop = artist_info["popularity"]
        artist_genres = artist_info["genres"]

        #Album
        album = track["track"]["album"]["name"]

        #Popularity of the track
        track_pop = track["track"]["popularity"]
        
        #Track Name
        track_name = track["track"]["name"]
        
        #Track URI
        track_uri = track["track"]["uri"]

# %% [markdown]
# # TRACK URI

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_uri = track["track"]["uri"]
        track_name = track["track"]["name"]
        result = track_uri#, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


track_u = get_tracks()

# %%
t_uri=pd.DataFrame(track_u)
t_uri=t_uri.rename(columns={0:'track_uri'})
t_uri=t_uri['track_uri'].str.lstrip('spotify:track:')
t_uri=pd.DataFrame(t_uri)

# %% [markdown]
# # ARTIST NAME

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        artist_name = track["track"]["artists"][0]["name"]
        result = artist_name
        tracks.append(result)

    return tracks


artist_name = get_tracks()

# %%
a_name=pd.DataFrame(artist_name).reset_index()
a_name=a_name.rename(columns={0:'artist_name'})
a_name['year']=1982

# %% [markdown]
# # TRACK NAME

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_name = track["track"]["name"]
        result = track_name#, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


track_name = get_tracks()

# %%
t_name=pd.DataFrame(track_name).reset_index()
t_name=t_name.rename(columns={0:'track_name'})

# %% [markdown]
# # AUDIO FEATURES

# %% [markdown]
# def get_playlist_uri(playlist_link):
#     return playlist_link.split("/")[-1].split("?")[0]
#
#
# def get_tracks():
#     tracks = []
#     playlist_uri = get_playlist_uri(playlist_link)
#     for track in sp.playlist_tracks(playlist_uri)["items"]:
#         track_name = track["track"]["name"]
#         track_uri = track["track"]["uri"]
#         result = sp.audio_features(track_uri)
#         tracks.append(result)
#
#     return tracks
#
#
# audio = get_tracks()

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_name = track["track"]["name"]
        track_uri = track["track"]["uri"]
        result = sp.audio_features(track_uri)[0]
        tracks.append(result)
        #result=pd.concat([sp.audio_features, tracks], axis=0)
    return tracks


audio = get_tracks()

# %% [markdown]
# audio

# %%
audio_fea=pd.DataFrame(audio).reset_index()
audio_fea=audio_fea.drop(columns=['type','uri','track_href','analysis_url'])
audio_fea=audio_fea.rename(columns={'id':'track_uri'})

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)
        artist_genres = artist_info["genres"]
        result = artist_genres
        tracks.append(result)

    return tracks


track_genres = get_tracks()

# %%
genres=pd.DataFrame(track_genres)
genres=genres.rename(columns={0:'primary_genre',1:'sub_genre_1', 2:'sub_genre_2'})
genres= genres[['primary_genre','sub_genre_1','sub_genre_2']].reset_index()

# %%
final_1982_df=a_name.merge(t_name, how='left', on='index')
final_1982_df=final_1982_df.merge(genres, how='left', on='index')
final_1982_df=final_1982_df.merge(audio_fea, how='left', on='index')
final_1982_df
# Out:
#     index                  artist_name  year  \
# 0       0           Olivia Newton-John  1982
# 1       1                     Survivor  1982
# 2       2  Joan Jett & the Blackhearts  1982
# 3       3               Paul McCartney  1982
# 4       4            The J. Geils Band  1982
# ..    ...                          ...   ...
# 94     94                Stevie Wonder  1982
# 95     95                     Loverboy  1982
# 96     96            Christopher Cross  1982
# 97     97                 Kenny Rogers  1982
# 98     98                 Stevie Nicks  1982
#
#                                track_name    primary_genre  \
# 0                                Physical  adult standards
# 1                        Eye of the Tiger       album rock
# 2                     I Love Rock 'N Roll        glam punk
# 3                         Ebony And Ivory       album rock
# 4                              Centerfold       album rock
# ..                                    ...              ...
# 94               Do I Do - Single Version             funk
# 95                Working for the Weekend       album rock
# 96  Arthur's Theme (Best That You Can Do)  adult standards
# 97     Through The Years - Single Version  adult standards
# 98      Edge of Seventeen - 2016 Remaster       album rock
#
#               sub_genre_1    sub_genre_2  danceability  energy  key  ...  \
# 0        australian dance  bubblegum pop         0.829   0.737    4  ...
# 1               hard rock           rock         0.815   0.438    0  ...
# 2                    rock           None         0.535   0.716    4  ...
# 3              beatlesque   classic rock         0.639   0.458    4  ...
# 4                art rock     blues rock         0.653   0.677    0  ...
# ..                    ...            ...           ...     ...  ...  ...
# 94                 motown    quiet storm         0.713   0.862   11  ...
# 95  classic canadian rock   classic rock         0.515   0.766    7  ...
# 96             album rock          disco         0.526   0.515    9  ...
# 97    classic country pop        country         0.554   0.487    0  ...
# 98         heartland rock    mellow gold         0.591   0.804    0  ...
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0      0       0.0441        0.1300          0.000063    0.2840    0.857
# 1      0       0.0346        0.2160          0.000466    0.0787    0.552
# 2      1       0.0431        0.3260          0.000000    0.6590    0.901
# 3      1       0.0343        0.1520          0.000000    0.1680    0.805
# 4      1       0.0396        0.2490          0.000000    0.4030    0.888
# ..   ...          ...           ...               ...       ...      ...
# 94     1       0.0519        0.0948          0.000012    0.3300    0.894
# 95     1       0.0343        0.0249          0.001030    0.4550    0.774
# 96     1       0.0389        0.1690          0.000816    0.1810    0.518
# 97     1       0.0264        0.3480          0.000001    0.2130    0.258
# 98     1       0.0454        0.3270          0.000006    0.0818    0.658
#
#       tempo               track_uri duration_ms  time_signature
# 0   123.878  3FuL7jThtUAjneBm6puQNk      222400               4
# 1   108.965  2HHtWyy5CgaQbC7XSoOb0e      243773               4
# 2    94.379  2Cdvbe2G4hZsnhNMKyGrie      175173               4
# 3    80.692  1h3bcnnIm72UnemGIfm0iZ      220773               4
# 4   114.370  1ynmMEK1fkyiZ6Z6F3ThEt      216533               4
# ..      ...                     ...         ...             ...
# 94  113.268  5OUfoG39D9qGF6FcvX3Yp7      301800               4
# 95  146.911  35k31HZI4z9PbBOioaI4dZ      221000               4
# 96  136.543  5fnOrhQ4KgT5irGCjIccGH      234493               4
# 97  131.127  5TSSjhWoGjWJfkfa6lziFJ      285027               4
# 98  111.457  7L3b6iaVhDVjfo52Hbvh9Z      329413               4
#
# [99 rows x 21 columns]

# %% [markdown]
# # TIME SIGNATURE PERCENTAGES

# %%
time_sig=final_1982_df[final_1982_df['time_signature']==4]
percent_time_sig=time_sig['track_name'].count()/final_1982_df['track_name'].count() *100
percent_time_sig
# Out:
# 96.96969696969697

# %% [markdown]
# # GENRES

# %%
genres=final_1982_df[['year','primary_genre','sub_genre_1','sub_genre_2']]
genres['genre_count'] =1
# Out:
# C:\Users\vital\AppData\Local\Temp\ipykernel_7588\1057796131.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genres['genre_count'] =1

# %%
primary_g=genres[['year','primary_genre', 'genre_count']]
primary_g=primary_g.groupby(['year','primary_genre'])['genre_count'].sum()
primary_g=pd.DataFrame(primary_g).reset_index().sort_values(['genre_count'], ascending=False)
primary_g=primary_g.reset_index()
primary_g=primary_g.drop(columns=['index'])
primary_g=primary_g.reset_index()
primary_g['pg_count']= primary_g['primary_genre'].count()

# %%
sub_g_1=genres[['year','sub_genre_1', 'genre_count']]
sub_g_1=sub_g_1.groupby(['year','sub_genre_1'])['genre_count'].sum()
sub_g_1=pd.DataFrame(sub_g_1).reset_index().sort_values(['genre_count'], ascending=False)
sub_g_1=sub_g_1.reset_index()
sub_g_1=sub_g_1.drop(columns=['index'])
sub_g_1=sub_g_1.reset_index()
sub_g_1['s1_count']= sub_g_1['sub_genre_1'].count()

# %%
sub_g_2=genres[['year','sub_genre_2', 'genre_count']]
sub_g_2=sub_g_2.groupby(['year','sub_genre_2'])['genre_count'].sum()
sub_g_2=pd.DataFrame(sub_g_2).reset_index().sort_values(['genre_count'], ascending=False)
sub_g_2=sub_g_2.reset_index()
sub_g_2=sub_g_2.drop(columns=['index'])
sub_g_2=sub_g_2.reset_index()
sub_g_2['s2_count']= sub_g_2['sub_genre_2'].count()

# %%
genre_1982_df=primary_g.merge(sub_g_1, how='left', on='index')
genre_1982_df=genre_1982_df.merge(sub_g_2, how='left', on='index')
genre_1982_df=genre_1982_df.drop(columns=['year_y','year']).head(15)
genre_1982_df=genre_1982_df.rename(columns={'year_x':'year','genre_count_x':'p_gen_count','genre_count_y':'sg1_count','genre_count':'sg2_count'})
genre_1982_df
# Out:
#     index  year        primary_genre  p_gen_count  pg_count     sub_genre_1  \
# 0       0  1982           album rock           45        17    classic rock
# 1       1  1982      adult standards           16        17        art rock
# 2       2  1982                disco           10        17           disco
# 3       3  1982          mellow gold            5        17     mellow gold
# 4       4  1982  classic country pop            4        17            funk
# 5       5  1982              country            2        17       soft rock
# 6       6  1982                 funk            2        17   bubblegum pop
# 7       7  1982            glam punk            2        17       candy pop
# 8       8  1982            glam rock            2        17    country dawn
# 9       9  1982         new romantic            2        17            rock
# 10     10  1982           blues rock            1        17    new wave pop
# 11     11  1982            cyberpunk            1        17        new wave
# 12     12  1982            dance pop            1        17    new romantic
# 13     13  1982             art rock            1        17          motown
# 14     14  1982                 folk            1        17  heartland rock
#
#     sg1_count  s1_count    sub_genre_2  sg2_count  s2_count
# 0          20        34   classic rock         15        25
# 1           9        34   country rock         15        25
# 2           6        34    mellow gold         10        25
# 3           5        34      hard rock          5        25
# 4           5        34   new wave pop          4        25
# 5           4        34     girl group          4        25
# 6           3        34      soft rock          3        25
# 7           3        34    quiet storm          3        25
# 8           2        34     post-disco          3        25
# 9           2        34     blues rock          2        25
# 10          2        34     piano rock          2        25
# 11          2        34   new romantic          2        25
# 12          2        34         motown          2        25
# 13          2        34      jazz funk          2        25
# 14          2        34  bubblegum pop          2        25

# %% [markdown]
# # AUDIO FEATURES DANCEABILITY, ENERGY, Tempo

# %%
top_10_dance_avg=final_1982_df.head(10)
top_10_dance_avg=top_10_dance_avg['danceability'].sum()/top_10_dance_avg['danceability'].count()*100
num_1_dance=final_1982_df['danceability']*100

dance_df=pd.DataFrame({'dance_avg':[final_1982_df['danceability'].sum()/final_1982_df['danceability'].count()*100],
                 'top10_dance_avg':[top_10_dance_avg],
                 'top_song_dance': [num_1_dance.iloc[0]]
                })
dance_df=dance_df.reset_index()
dance_df
# Out:
#    index  dance_avg  top10_dance_avg  top_song_dance
# 0      0  61.348485            71.29            82.9

# %%
top_10_energy_avg=final_1982_df.head(10)
top_10_energy_avg=top_10_energy_avg['energy'].sum()/top_10_energy_avg['energy'].count()*100
num_1_energy=final_1982_df['energy']*100

energy_df=pd.DataFrame({'energy_avg':[final_1982_df['energy'].sum()/final_1982_df['energy'].count()*100],
                 'top10_energy_avg':[top_10_energy_avg],
                 'top_song_energy': [num_1_energy.iloc[0]]
                })
energy_df=energy_df.reset_index()
energy_df
# Out:
#    index  energy_avg  top10_energy_avg  top_song_energy
# 0      0   58.280808             58.67             73.7

# %%
top_10_live_avg=final_1982_df.head(10)
top_10_live_avg=top_10_live_avg['liveness'].sum()/top_10_live_avg['liveness'].count()*100
num_1_live=final_1982_df['liveness']*100

live_df=pd.DataFrame({'live_avg':[final_1982_df['liveness'].sum()/final_1982_df['liveness'].count()*100],
                 'top10_live_avg':[top_10_live_avg],
                 'top_song_live': [num_1_live.iloc[0]]
                })
live_df=live_df.reset_index()
live_df
# Out:
#    index   live_avg  top10_live_avg  top_song_live
# 0      0  19.211414          22.216           28.4

# %%
energy_1982_df=dance_df.merge(live_df, how='left', on='index')
energy_1982_df=energy_1982_df.merge(energy_df, how='left', on='index')
energy_1982_df['year']=1982
energy_1982_df
# Out:
#    index  dance_avg  top10_dance_avg  top_song_dance   live_avg  \
# 0      0  61.348485            71.29            82.9  19.211414
#
#    top10_live_avg  top_song_live  energy_avg  top10_energy_avg  \
# 0          22.216           28.4   58.280808             58.67
#
#    top_song_energy  year
# 0             73.7  1982

# %%
top_10_duration_avg=final_1982_df.head(10)
top_10_duration_avg=(top_10_duration_avg['duration_ms'].sum()/top_10_duration_avg['duration_ms'].count())/(60*1000)
num_1_duration=(final_1982_df['duration_ms'])/(60*1000)

duration_df=pd.DataFrame({'dur_avg':[(final_1982_df['duration_ms'].sum()/final_1982_df['duration_ms'].count())/(60*1000)],
                 'top10_dur_avg':[top_10_duration_avg],
                 'top_song_dur': [num_1_duration.iloc[0]]
                })
duration_df=duration_df.reset_index()
duration_df
# Out:
#    index   dur_avg  top10_dur_avg  top_song_dur
# 0      0  3.887549       3.871397      3.706667

# %%
top_10_tempo_avg=final_1982_df.head(10)
top_10_tempo_avg=(top_10_tempo_avg['tempo'].sum()/top_10_tempo_avg['tempo'].count())
num_1_tempo=(final_1982_df['tempo'])

tempo_df=pd.DataFrame({'tempo_avg':[(final_1982_df['tempo'].sum()/final_1982_df['tempo'].count())],
                 'top10_tempo_avg':[top_10_tempo_avg],
                 'top_song_tempo': [num_1_tempo.iloc[0]]
                })
tempo_df=tempo_df.reset_index()
tempo_df
# Out:
#    index   tempo_avg  top10_tempo_avg  top_song_tempo
# 0      0  124.600758         114.1552         123.878

# %%
final_1982_df.head(2)
# Out:
#    index         artist_name  year        track_name    primary_genre  \
# 0      0  Olivia Newton-John  1982          Physical  adult standards
# 1      1            Survivor  1982  Eye of the Tiger       album rock
#
#         sub_genre_1    sub_genre_2  danceability  energy  key  ...  mode  \
# 0  australian dance  bubblegum pop         0.829   0.737    4  ...     0
# 1         hard rock           rock         0.815   0.438    0  ...     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0441         0.130          0.000063    0.2840    0.857  123.878
# 1       0.0346         0.216          0.000466    0.0787    0.552  108.965
#
#                 track_uri duration_ms  time_signature
# 0  3FuL7jThtUAjneBm6puQNk      222400               4
# 1  2HHtWyy5CgaQbC7XSoOb0e      243773               4
#
# [2 rows x 21 columns]
