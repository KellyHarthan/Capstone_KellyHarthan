# %% [markdown]
# #Authentication - without user
# client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
# sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
sp = spotipy.Spotify()
import requests
import pandas as pd

# %%
from __future__ import print_function
import sys
import spotipy.util as util

# %%
CLIENT_ID = 'c7d16c8600ab433ea5aede2202285c1e'
CLIENT_SECRET = '69b7f20b150845a1ae6427a66f14d780'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer BQDLLLg6_qZyR6QTO1aLkIzGrTA8uGkSkfN87GbLQEr9uxhUZulWI_QDeKaYOdbPpH_ArR1sO7rvD-06iCJIGalczxgcDKGlJCo6ZjjqMT2SFaeFIZGMUnllXDYNIRsHtoixTSYDDPn2wuNAprMQ-doZuM-KkgguXUwyYuTA6Mm3I6-jPvI1hYg5kvFGWVsjU3I'.format(token=access_token)
}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

# %%
response = r.json()
response
# Out:
# {'danceability': 0.54,
#  'energy': 0.59,
#  'key': 0,
#  'loudness': -4.359,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.446,
#  'instrumentalness': 0,
#  'liveness': 0.14,
#  'valence': 0.267,
#  'tempo': 119.878,
#  'type': 'audio_features',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y',
#  'track_href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0igZArWVi6Iz0rj35c1Y',
#  'duration_ms': 234910,
#  'time_signature': 4}

# %%
headers = {
    'Authorization': 'Bearer BQDRp_O-M50QQ8JxMKmOmuQAGntPmPcXYr4MglUA7W96J3n7mUFIfJssGr923qrV0sVKDgmB91hqiW4E41TxOLEd8S86In9I-39eAzO2dSYNvyjc1L4ZbXu_DsrFDc_8meXku40KEWd9EpkCzW8RaUrutfW7U5CnrK9TVB2AVri7oXtB-H407y2QbH6v98YAvf8'.format(token=access_token)
}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

# %%
response = r.json()
response
# Out:
# {'danceability': 0.54,
#  'energy': 0.59,
#  'key': 0,
#  'loudness': -4.359,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.446,
#  'instrumentalness': 0,
#  'liveness': 0.14,
#  'valence': 0.267,
#  'tempo': 119.878,
#  'type': 'audio_features',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y',
#  'track_href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0igZArWVi6Iz0rj35c1Y',
#  'duration_ms': 234910,
#  'time_signature': 4}

# %% [markdown]
# artist= 'Moses Sumney'
# track= 'Lonely World'
#
# track_id = sp.search(q='artist:' + artist + ' track:' + track, type='track')

# %%
SEARCH_URL="https://api.spotify.com/v1/search?q=Thriller&type=track"
res=requests.get(SEARCH_URL, headers=headers)  
res
# Out:
# <Response [200]>

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track = 'About Damn Time'

# actual GET request with proper header
r2 = requests.get(BASE_URL + 'search?q=' + track +'&type=track', headers=headers)
#r2 = requests.get(BASE_URL + 'search/' + ' track:' + track, type='track')
r2
# Out:
# <Response [200]>

# %%
search = r2.json()
search
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=About+Damn+Time&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56oDRnqbIiwx4mymNEv7dS'},
#        'href': 'https://api.spotify.com/v1/artists/56oDRnqbIiwx4mymNEv7dS',
#        'id': '56oDRnqbIiwx4mymNEv7dS',
#        'name': 'Lizzo',
#        'type': 'artist',
#        'uri': 'spotify:artist:56oDRnqbIiwx4mymNEv7dS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
# ...

# %%
SEARCH_URL="https://api.spotify.com/v1/search?q=Lizzo&type=artist"
res=requests.get(SEARCH_URL, headers=headers)  
res
# Out:
# <Response [200]>

# %%
# base URL of all Spotify API endpoints
S2_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
artist = 'Lizzo'

# actual GET request with proper header
r2 = requests.get(S2_URL + 'search?q=' + artist + '&type=artist', headers=headers)
r2
# Out:
# <Response [200]>

# %%
search = res.json()
search
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Lizzo&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56oDRnqbIiwx4mymNEv7dS'},
#     'followers': {'href': None, 'total': 4879153},
#     'genres': ['dance pop',
#      'escape room',
#      'minnesota hip hop',
#      'pop',
#      'trap queen'],
#     'href': 'https://api.spotify.com/v1/artists/56oDRnqbIiwx4mymNEv7dS',
#     'id': '56oDRnqbIiwx4mymNEv7dS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb0d66b3670294bf801847dae2',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051740d66b3670294bf801847dae2',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1780d66b3670294bf801847dae2',
#       'width': 160}],
#     'name': 'Lizzo',
#     'popularity': 81,
#     'type': 'artist',
# ...

# %%
artist_df=pd.DataFrame(search)

artist_df
# Out:
#                                                      tracks
# href      https://api.spotify.com/v1/search?query=About+...
# items     [{'album': {'album_type': 'single', 'artists':...
# limit                                                    20
# next      https://api.spotify.com/v1/search?query=About+...
# offset                                                    0
# previous                                               None
# total                                                  1416
