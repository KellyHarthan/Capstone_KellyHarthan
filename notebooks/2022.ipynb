# %% [markdown]
# # PERMISSIONS AUTHORIZATION

# %%
import requests
import pandas as pd

# %%
CLIENT_ID = 'c7d16c8600ab433ea5aede2202285c1e'
CLIENT_SECRET = '69b7f20b150845a1ae6427a66f14d780'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
#needs to be updated every hour
headers = {
    'Authorization': 'Bearer BQDlbyPBnFHm_qeBsuzAMRQa2GGDxu1RUo8rBki12_ZdN-FgTN6EBf2uG2q5Mqxl0hdblGVcIgEKAlFLKoVtBgqfs4QRoYHpUWTcaPUK4BI7FN0gWKCxVFh_JWTztnO1--wyNYD4pRSNafwFsM5slax8N6QphYDOya5KIX7I-yLEEHqXaWg5_T28fD3hXbr5DtY'.format(token=access_token)
}

# %% [markdown]
# # PULLING IN BILLBOARD 1982

# %%
import spotipy
sp = spotipy.Spotify()
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/embed/playlist/6UeSakyzhiEt4NB3UAd6NQ?utm_source=generator"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
    for track in sp.playlist_tracks(playlist_URI)["items"]:
        #URI
        track_uri = track["track"]["uri"]

        #Track name
        track_name = track["track"]["name"]

        #Main Artist
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)

        #Name, popularity, genre
        artist_name = track["track"]["artists"][0]["name"]
        
        #artist_pop = artist_info["popularity"]
        artist_genres = artist_info["genres"]

        #Album
        album = track["track"]["album"]["name"]

        #Popularity of the track
        track_pop = track["track"]["popularity"]
        
        #Track Name
        track_name = track["track"]["name"]
        
        #Track URI
        track_uri = track["track"]["uri"]

# %% [markdown]
# # TRACK URI

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_uri = track["track"]["uri"]
        track_name = track["track"]["name"]
        result = track_uri#, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


track_u = get_tracks()

# %%
t_uri=pd.DataFrame(track_u)
t_uri=t_uri.rename(columns={0:'track_uri'})
t_uri=t_uri['track_uri'].str.lstrip('spotify:track:')
t_uri=pd.DataFrame(t_uri)
t_uri
# Out:
#                  track_uri
# 0   2KukL7UlQ8TdvpaA7bY3ZJ
# 1   1PckUlxKqWQs3RlWXVBLw3
# 2   4LRPiXqCikLlN15c3yImP7
# 3   29d0nY7TzCoi22XBqDQkiP
# 4   59nOXPmaKlBfGMDeOVGrIK
# ..                     ...
# 95  0T5iIrXA4p5GsubkhuBIKV
# 96  5CzixCxDkRXX9mScCmah8O
# 97  0R1REdJZIDy7IS3DybdBce
# 98  1797zYiX4cKosMH836X9Gt
# 99  2tTmW7RDtMQtBk7m2rYeSw
#
# [100 rows x 1 columns]

# %% [markdown]
# # ARTIST NAME

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        artist_name = track["track"]["artists"][0]["name"]
        result = artist_name
        tracks.append(result)

    return tracks


artist_name = get_tracks()

# %%
a_name=pd.DataFrame(artist_name).reset_index()
a_name=a_name.rename(columns={0:'artist_name'})
a_name['year']=2022

# %% [markdown]
# # TRACK NAME

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_name = track["track"]["name"]
        result = track_name#, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


track_name = get_tracks()

# %%
t_name=pd.DataFrame(track_name).reset_index()
t_name=t_name.rename(columns={0:'track_name'})
t_name
# Out:
#     index                                         track_name
# 0       0                                      BREAK MY SOUL
# 1       1                                    About Damn Time
# 2       2                                          As It Was
# 3       3  Running Up That Hill (A Deal With God) - 2018 ...
# 4       4                    WAIT FOR U (feat. Drake & Tems)
# ..    ...                                                ...
# 95     95                                  Until I Found You
# 96     96                                          Un Ratito
# 97     97                         Best Thing Since Backroads
# 98     98                                       La Corriente
# 99     99              Quevedo: Bzrp Music Sessions, Vol. 52
#
# [100 rows x 2 columns]

# %% [markdown]
# # AUDIO FEATURES

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        #track_name = track["track"]["name"]
        track_uri = track["track"]["uri"]
        result = sp.audio_features(track_uri)[0]
        tracks.append(result)

    return tracks


audio = get_tracks()

# %%
audio
# Out:
# [{'danceability': 0.687,
#   'energy': 0.887,
#   'key': 1,
#   'loudness': -5.04,
#   'mode': 0,
#   'speechiness': 0.0826,
#   'acousticness': 0.0575,
#   'instrumentalness': 2.21e-06,
#   'liveness': 0.27,
#   'valence': 0.853,
#   'tempo': 114.941,
#   'type': 'audio_features',
#   'id': '2KukL7UlQ8TdvpaA7bY3ZJ',
#   'uri': 'spotify:track:2KukL7UlQ8TdvpaA7bY3ZJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2KukL7UlQ8TdvpaA7bY3ZJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2KukL7UlQ8TdvpaA7bY3ZJ',
#   'duration_ms': 278282,
#   'time_signature': 4},
#  {'danceability': 0.836,
#   'energy': 0.743,
#   'key': 10,
#   'loudness': -6.305,
#   'mode': 0,
#   'speechiness': 0.0656,
#   'acousticness': 0.0995,
#   'instrumentalness': 0,
#   'liveness': 0.335,
#   'valence': 0.722,
#   'tempo': 108.966,
#   'type': 'audio_features',
#   'id': '1PckUlxKqWQs3RlWXVBLw3',
#   'uri': 'spotify:track:1PckUlxKqWQs3RlWXVBLw3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1PckUlxKqWQs3RlWXVBLw3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PckUlxKqWQs3RlWXVBLw3',
#   'duration_ms': 191822,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.731,
#   'key': 6,
#   'loudness': -5.338,
#   'mode': 0,
#   'speechiness': 0.0557,
#   'acousticness': 0.342,
#   'instrumentalness': 0.00101,
#   'liveness': 0.311,
#   'valence': 0.662,
#   'tempo': 173.93,
#   'type': 'audio_features',
#   'id': '4LRPiXqCikLlN15c3yImP7',
#   'uri': 'spotify:track:4LRPiXqCikLlN15c3yImP7',
#   'track_href': 'https://api.spotify.com/v1/tracks/4LRPiXqCikLlN15c3yImP7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LRPiXqCikLlN15c3yImP7',
#   'duration_ms': 167303,
#   'time_signature': 4},
#  {'danceability': 0.625,
#   'energy': 0.533,
#   'key': 10,
#   'loudness': -11.903,
#   'mode': 0,
#   'speechiness': 0.0596,
#   'acousticness': 0.659,
#   'instrumentalness': 0.00266,
#   'liveness': 0.0546,
#   'valence': 0.139,
#   'tempo': 108.296,
#   'type': 'audio_features',
#   'id': '29d0nY7TzCoi22XBqDQkiP',
#   'uri': 'spotify:track:29d0nY7TzCoi22XBqDQkiP',
#   'track_href': 'https://api.spotify.com/v1/tracks/29d0nY7TzCoi22XBqDQkiP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/29d0nY7TzCoi22XBqDQkiP',
#   'duration_ms': 300840,
#   'time_signature': 4},
#  {'danceability': 0.463,
#   'energy': 0.642,
#   'key': 1,
#   'loudness': -4.474,
#   'mode': 1,
#   'speechiness': 0.34,
#   'acousticness': 0.314,
#   'instrumentalness': 0,
#   'liveness': 0.0686,
#   'valence': 0.339,
#   'tempo': 83.389,
#   'type': 'audio_features',
#   'id': '59nOXPmaKlBfGMDeOVGrIK',
#   'uri': 'spotify:track:59nOXPmaKlBfGMDeOVGrIK',
#   'track_href': 'https://api.spotify.com/v1/tracks/59nOXPmaKlBfGMDeOVGrIK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59nOXPmaKlBfGMDeOVGrIK',
#   'duration_ms': 189893,
#   'time_signature': 4},
#  {'danceability': 0.905,
#   'energy': 0.563,
#   'key': 8,
#   'loudness': -6.135,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.0254,
#   'instrumentalness': 9.71e-06,
#   'liveness': 0.113,
#   'valence': 0.324,
#   'tempo': 106.998,
#   'type': 'audio_features',
#   'id': '1rDQ4oMwGJI7B4tovsBOxc',
#   'uri': 'spotify:track:1rDQ4oMwGJI7B4tovsBOxc',
#   'track_href': 'https://api.spotify.com/v1/tracks/1rDQ4oMwGJI7B4tovsBOxc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rDQ4oMwGJI7B4tovsBOxc',
#   'duration_ms': 173948,
#   'time_signature': 4},
#  {'danceability': 0.686,
#   'energy': 0.507,
#   'key': 1,
#   'loudness': -7.097,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.626,
#   'instrumentalness': 7.51e-05,
#   'liveness': 0.383,
#   'valence': 0.69,
#   'tempo': 168.955,
#   'type': 'audio_features',
#   'id': '5CM4UuQ9Gnd6K2YyKGPMoK',
#   'uri': 'spotify:track:5CM4UuQ9Gnd6K2YyKGPMoK',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CM4UuQ9Gnd6K2YyKGPMoK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CM4UuQ9Gnd6K2YyKGPMoK',
#   'duration_ms': 232115,
#   'time_signature': 4},
#  {'danceability': 0.911,
#   'energy': 0.712,
#   'key': 1,
#   'loudness': -5.105,
#   'mode': 0,
#   'speechiness': 0.0817,
#   'acousticness': 0.0901,
#   'instrumentalness': 2.68e-05,
#   'liveness': 0.0933,
#   'valence': 0.425,
#   'tempo': 92.005,
#   'type': 'audio_features',
#   'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'duration_ms': 178567,
#   'time_signature': 4},
#  {'danceability': 0.768,
#   'energy': 0.714,
#   'key': 10,
#   'loudness': -5.11,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.352,
#   'instrumentalness': 0,
#   'liveness': 0.15,
#   'valence': 0.842,
#   'tempo': 131.443,
#   'type': 'audio_features',
#   'id': '4h4QlmocP3IuwYEj2j14p8',
#   'uri': 'spotify:track:4h4QlmocP3IuwYEj2j14p8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4h4QlmocP3IuwYEj2j14p8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4h4QlmocP3IuwYEj2j14p8',
#   'duration_ms': 163026,
#   'time_signature': 4},
#  {'danceability': 0.714,
#   'energy': 0.728,
#   'key': 10,
#   'loudness': -4.595,
#   'mode': 1,
#   'speechiness': 0.0468,
#   'acousticness': 0.298,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.901,
#   'tempo': 114.996,
#   'type': 'audio_features',
#   'id': '1qEmFfgcLObUfQm0j1W2CK',
#   'uri': 'spotify:track:1qEmFfgcLObUfQm0j1W2CK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1qEmFfgcLObUfQm0j1W2CK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qEmFfgcLObUfQm0j1W2CK',
#   'duration_ms': 177955,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -6.009,
#   'mode': 1,
#   'speechiness': 0.0751,
#   'acousticness': 0.121,
#   'instrumentalness': 0,
#   'liveness': 0.121,
#   'valence': 0.472,
#   'tempo': 100.964,
#   'type': 'audio_features',
#   'id': '0O6u0VJ46W86TxN9wgyqDj',
#   'uri': 'spotify:track:0O6u0VJ46W86TxN9wgyqDj',
#   'track_href': 'https://api.spotify.com/v1/tracks/0O6u0VJ46W86TxN9wgyqDj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0O6u0VJ46W86TxN9wgyqDj',
#   'duration_ms': 192841,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.525,
#   'key': 11,
#   'loudness': -6.9,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.44,
#   'instrumentalness': 6.7e-06,
#   'liveness': 0.0921,
#   'valence': 0.531,
#   'tempo': 80.87,
#   'type': 'audio_features',
#   'id': '3USxtqRwSYz57Ewm6wWRMp',
#   'uri': 'spotify:track:3USxtqRwSYz57Ewm6wWRMp',
#   'track_href': 'https://api.spotify.com/v1/tracks/3USxtqRwSYz57Ewm6wWRMp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3USxtqRwSYz57Ewm6wWRMp',
#   'duration_ms': 238805,
#   'time_signature': 4},
#  {'danceability': 0.78,
#   'energy': 0.689,
#   'key': 7,
#   'loudness': -5.668,
#   'mode': 1,
#   'speechiness': 0.141,
#   'acousticness': 0.0368,
#   'instrumentalness': 9.69e-06,
#   'liveness': 0.0698,
#   'valence': 0.642,
#   'tempo': 115.042,
#   'type': 'audio_features',
#   'id': '1xzi1Jcr7mEi9K2RfzLOqS',
#   'uri': 'spotify:track:1xzi1Jcr7mEi9K2RfzLOqS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xzi1Jcr7mEi9K2RfzLOqS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xzi1Jcr7mEi9K2RfzLOqS',
#   'duration_ms': 225389,
#   'time_signature': 4},
#  {'danceability': 0.608,
#   'energy': 0.745,
#   'key': 1,
#   'loudness': -4.13,
#   'mode': 1,
#   'speechiness': 0.0277,
#   'acousticness': 0.0226,
#   'instrumentalness': 6.47e-06,
#   'liveness': 0.0942,
#   'valence': 0.464,
#   'tempo': 102.025,
#   'type': 'audio_features',
#   'id': '48UKTR66uUOT9LaUvooTNx',
#   'uri': 'spotify:track:48UKTR66uUOT9LaUvooTNx',
#   'track_href': 'https://api.spotify.com/v1/tracks/48UKTR66uUOT9LaUvooTNx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/48UKTR66uUOT9LaUvooTNx',
#   'duration_ms': 224427,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.657,
#   'key': 11,
#   'loudness': -5.24,
#   'mode': 0,
#   'speechiness': 0.0318,
#   'acousticness': 0.373,
#   'instrumentalness': 0.00107,
#   'liveness': 0.126,
#   'valence': 0.252,
#   'tempo': 196.0,
#   'type': 'audio_features',
#   'id': '3cBsEDNhFI9E82vPj3kvi3',
#   'uri': 'spotify:track:3cBsEDNhFI9E82vPj3kvi3',
#   'track_href': 'https://api.spotify.com/v1/tracks/3cBsEDNhFI9E82vPj3kvi3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3cBsEDNhFI9E82vPj3kvi3',
#   'duration_ms': 178520,
#   'time_signature': 3},
#  {'danceability': 0.65,
#   'energy': 0.715,
#   'key': 5,
#   'loudness': -5.198,
#   'mode': 0,
#   'speechiness': 0.253,
#   'acousticness': 0.0993,
#   'instrumentalness': 0.000291,
#   'liveness': 0.126,
#   'valence': 0.187,
#   'tempo': 106.672,
#   'type': 'audio_features',
#   'id': '1IHWl5LamUGEuP4ozKQSXZ',
#   'uri': 'spotify:track:1IHWl5LamUGEuP4ozKQSXZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1IHWl5LamUGEuP4ozKQSXZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1IHWl5LamUGEuP4ozKQSXZ',
#   'duration_ms': 243717,
#   'time_signature': 4},
#  {'danceability': 0.591,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -5.484,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.0383,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.478,
#   'tempo': 169.928,
#   'type': 'audio_features',
#   'id': '5HCyWlXZPP0y6Gqq8TgA20',
#   'uri': 'spotify:track:5HCyWlXZPP0y6Gqq8TgA20',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HCyWlXZPP0y6Gqq8TgA20',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HCyWlXZPP0y6Gqq8TgA20',
#   'duration_ms': 141806,
#   'time_signature': 4},
#  {'danceability': 0.935,
#   'energy': 0.807,
#   'key': 11,
#   'loudness': -3.838,
#   'mode': 0,
#   'speechiness': 0.114,
#   'acousticness': 0.0514,
#   'instrumentalness': 0,
#   'liveness': 0.349,
#   'valence': 0.813,
#   'tempo': 106.017,
#   'type': 'audio_features',
#   'id': '6Zu3aw7FfjAF9WA0fA81Oq',
#   'uri': 'spotify:track:6Zu3aw7FfjAF9WA0fA81Oq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Zu3aw7FfjAF9WA0fA81Oq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Zu3aw7FfjAF9WA0fA81Oq',
#   'duration_ms': 173182,
#   'time_signature': 4},
#  {'danceability': 0.545,
#   'energy': 0.641,
#   'key': 10,
#   'loudness': -6.398,
#   'mode': 0,
#   'speechiness': 0.0998,
#   'acousticness': 0.00453,
#   'instrumentalness': 6.59e-05,
#   'liveness': 0.171,
#   'valence': 0.464,
#   'tempo': 121.892,
#   'type': 'audio_features',
#   'id': '1Hohk6AufHZOrrhMXZppax',
#   'uri': 'spotify:track:1Hohk6AufHZOrrhMXZppax',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Hohk6AufHZOrrhMXZppax',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Hohk6AufHZOrrhMXZppax',
#   'duration_ms': 215460,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.673,
#   'key': 0,
#   'loudness': -4.711,
#   'mode': 1,
#   'speechiness': 0.175,
#   'acousticness': 0.000307,
#   'instrumentalness': 2.41e-06,
#   'liveness': 0.093,
#   'valence': 0.366,
#   'tempo': 165.921,
#   'type': 'audio_features',
#   'id': '3F5CgOj3wFlRv51JsHbxhe',
#   'uri': 'spotify:track:3F5CgOj3wFlRv51JsHbxhe',
#   'track_href': 'https://api.spotify.com/v1/tracks/3F5CgOj3wFlRv51JsHbxhe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3F5CgOj3wFlRv51JsHbxhe',
#   'duration_ms': 218365,
#   'time_signature': 4},
#  {'danceability': 0.731,
#   'energy': 0.85,
#   'key': 9,
#   'loudness': -4.913,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.252,
#   'instrumentalness': 0,
#   'liveness': 0.605,
#   'valence': 0.644,
#   'tempo': 119.706,
#   'type': 'audio_features',
#   'id': '5uU1uuyaUIBOiiUSQG7Wl3',
#   'uri': 'spotify:track:5uU1uuyaUIBOiiUSQG7Wl3',
#   'track_href': 'https://api.spotify.com/v1/tracks/5uU1uuyaUIBOiiUSQG7Wl3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5uU1uuyaUIBOiiUSQG7Wl3',
#   'duration_ms': 157478,
#   'time_signature': 4},
#  {'danceability': 0.792,
#   'energy': 0.919,
#   'key': 2,
#   'loudness': -5.688,
#   'mode': 1,
#   'speechiness': 0.276,
#   'acousticness': 0.0381,
#   'instrumentalness': 5.1e-06,
#   'liveness': 0.368,
#   'valence': 0.22,
#   'tempo': 92.028,
#   'type': 'audio_features',
#   'id': '2mqTtvbKxH7SoEQ2oGAnsA',
#   'uri': 'spotify:track:2mqTtvbKxH7SoEQ2oGAnsA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mqTtvbKxH7SoEQ2oGAnsA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mqTtvbKxH7SoEQ2oGAnsA',
#   'duration_ms': 224473,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.797,
#   'key': 0,
#   'loudness': -5.927,
#   'mode': 1,
#   'speechiness': 0.0475,
#   'acousticness': 0.0826,
#   'instrumentalness': 0.000745,
#   'liveness': 0.0546,
#   'valence': 0.825,
#   'tempo': 139.994,
#   'type': 'audio_features',
#   'id': '4h9wh7iOZ0GGn8QVp4RAOB',
#   'uri': 'spotify:track:4h9wh7iOZ0GGn8QVp4RAOB',
#   'track_href': 'https://api.spotify.com/v1/tracks/4h9wh7iOZ0GGn8QVp4RAOB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4h9wh7iOZ0GGn8QVp4RAOB',
#   'duration_ms': 148486,
#   'time_signature': 4},
#  {'danceability': 0.742,
#   'energy': 0.527,
#   'key': 8,
#   'loudness': -6.892,
#   'mode': 0,
#   'speechiness': 0.0769,
#   'acousticness': 0.327,
#   'instrumentalness': 0,
#   'liveness': 0.25,
#   'valence': 0.638,
#   'tempo': 84.974,
#   'type': 'audio_features',
#   'id': '3o9kpgkIcffx0iSwxhuNI2',
#   'uri': 'spotify:track:3o9kpgkIcffx0iSwxhuNI2',
#   'track_href': 'https://api.spotify.com/v1/tracks/3o9kpgkIcffx0iSwxhuNI2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3o9kpgkIcffx0iSwxhuNI2',
#   'duration_ms': 169238,
#   'time_signature': 4},
#  {'danceability': 0.607,
#   'energy': 0.912,
#   'key': 8,
#   'loudness': -3.449,
#   'mode': 1,
#   'speechiness': 0.0611,
#   'acousticness': 0.124,
#   'instrumentalness': 0,
#   'liveness': 0.332,
#   'valence': 0.722,
#   'tempo': 134.944,
#   'type': 'audio_features',
#   'id': '200x8ONbPfFzByUr3fVz46',
#   'uri': 'spotify:track:200x8ONbPfFzByUr3fVz46',
#   'track_href': 'https://api.spotify.com/v1/tracks/200x8ONbPfFzByUr3fVz46',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/200x8ONbPfFzByUr3fVz46',
#   'duration_ms': 206107,
#   'time_signature': 4},
#  {'danceability': 0.554,
#   'energy': 0.535,
#   'key': 5,
#   'loudness': -8.959,
#   'mode': 0,
#   'speechiness': 0.186,
#   'acousticness': 0.0616,
#   'instrumentalness': 1.32e-05,
#   'liveness': 0.124,
#   'valence': 0.136,
#   'tempo': 105.865,
#   'type': 'audio_features',
#   'id': '1MpCaOeUWhox2Fgigbe1cL',
#   'uri': 'spotify:track:1MpCaOeUWhox2Fgigbe1cL',
#   'track_href': 'https://api.spotify.com/v1/tracks/1MpCaOeUWhox2Fgigbe1cL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1MpCaOeUWhox2Fgigbe1cL',
#   'duration_ms': 208014,
#   'time_signature': 4},
#  {'danceability': 0.903,
#   'energy': 0.519,
#   'key': 1,
#   'loudness': -9.151,
#   'mode': 1,
#   'speechiness': 0.26,
#   'acousticness': 0.281,
#   'instrumentalness': 0.000106,
#   'liveness': 0.155,
#   'valence': 0.587,
#   'tempo': 114.991,
#   'type': 'audio_features',
#   'id': '0314PeD1sQNonfVWix3B2K',
#   'uri': 'spotify:track:0314PeD1sQNonfVWix3B2K',
#   'track_href': 'https://api.spotify.com/v1/tracks/0314PeD1sQNonfVWix3B2K',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0314PeD1sQNonfVWix3B2K',
#   'duration_ms': 116727,
#   'time_signature': 4},
#  {'danceability': 0.44,
#   'energy': 0.317,
#   'key': 8,
#   'loudness': -9.258,
#   'mode': 1,
#   'speechiness': 0.0531,
#   'acousticness': 0.891,
#   'instrumentalness': 4.78e-06,
#   'liveness': 0.141,
#   'valence': 0.268,
#   'tempo': 169.914,
#   'type': 'audio_features',
#   'id': '6xGruZOHLs39ZbVccQTuPZ',
#   'uri': 'spotify:track:6xGruZOHLs39ZbVccQTuPZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xGruZOHLs39ZbVccQTuPZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xGruZOHLs39ZbVccQTuPZ',
#   'duration_ms': 233456,
#   'time_signature': 3},
#  {'danceability': 0.601,
#   'energy': 0.741,
#   'key': 2,
#   'loudness': -5.569,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.185,
#   'instrumentalness': 2.91e-05,
#   'liveness': 0.415,
#   'valence': 0.441,
#   'tempo': 153.96,
#   'type': 'audio_features',
#   'id': '6I3mqTwhRpn34SLVafSH7G',
#   'uri': 'spotify:track:6I3mqTwhRpn34SLVafSH7G',
#   'track_href': 'https://api.spotify.com/v1/tracks/6I3mqTwhRpn34SLVafSH7G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6I3mqTwhRpn34SLVafSH7G',
#   'duration_ms': 153190,
#   'time_signature': 4},
#  {'danceability': 0.556,
#   'energy': 0.63,
#   'key': 7,
#   'loudness': -8.15,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.000828,
#   'instrumentalness': 0.00468,
#   'liveness': 0.155,
#   'valence': 0.367,
#   'tempo': 149.147,
#   'type': 'audio_features',
#   'id': '0mKGwFMHzTprtS2vpR3b6s',
#   'uri': 'spotify:track:0mKGwFMHzTprtS2vpR3b6s',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mKGwFMHzTprtS2vpR3b6s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mKGwFMHzTprtS2vpR3b6s',
#   'duration_ms': 210372,
#   'time_signature': 5},
#  {'danceability': 0.912,
#   'energy': 0.655,
#   'key': 8,
#   'loudness': -6.029,
#   'mode': 0,
#   'speechiness': 0.162,
#   'acousticness': 0.315,
#   'instrumentalness': 3.39e-05,
#   'liveness': 0.0894,
#   'valence': 0.793,
#   'tempo': 91.942,
#   'type': 'audio_features',
#   'id': '0W6I02J9xcqK8MtSeosEXb',
#   'uri': 'spotify:track:0W6I02J9xcqK8MtSeosEXb',
#   'track_href': 'https://api.spotify.com/v1/tracks/0W6I02J9xcqK8MtSeosEXb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0W6I02J9xcqK8MtSeosEXb',
#   'duration_ms': 138293,
#   'time_signature': 4},
#  {'danceability': 0.804,
#   'energy': 0.674,
#   'key': 5,
#   'loudness': -5.453,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.294,
#   'instrumentalness': 1.18e-06,
#   'liveness': 0.115,
#   'valence': 0.292,
#   'tempo': 99.968,
#   'type': 'audio_features',
#   'id': '6Xom58OOXk2SoU711L2IXO',
#   'uri': 'spotify:track:6Xom58OOXk2SoU711L2IXO',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Xom58OOXk2SoU711L2IXO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Xom58OOXk2SoU711L2IXO',
#   'duration_ms': 245940,
#   'time_signature': 4},
#  {'danceability': 0.788,
#   'energy': 0.859,
#   'key': 2,
#   'loudness': -2.724,
#   'mode': 1,
#   'speechiness': 0.0856,
#   'acousticness': 0.281,
#   'instrumentalness': 0,
#   'liveness': 0.0424,
#   'valence': 0.822,
#   'tempo': 141.02,
#   'type': 'audio_features',
#   'id': '75MNhvTCCKsST3YqqUiU9r',
#   'uri': 'spotify:track:75MNhvTCCKsST3YqqUiU9r',
#   'track_href': 'https://api.spotify.com/v1/tracks/75MNhvTCCKsST3YqqUiU9r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/75MNhvTCCKsST3YqqUiU9r',
#   'duration_ms': 207853,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.82,
#   'key': 8,
#   'loudness': -6.073,
#   'mode': 1,
#   'speechiness': 0.0432,
#   'acousticness': 0.000682,
#   'instrumentalness': 0.000136,
#   'liveness': 0.0561,
#   'valence': 0.702,
#   'tempo': 124.85,
#   'type': 'audio_features',
#   'id': '3j1xkzTW8owIphkWV51V9s',
#   'uri': 'spotify:track:3j1xkzTW8owIphkWV51V9s',
#   'track_href': 'https://api.spotify.com/v1/tracks/3j1xkzTW8owIphkWV51V9s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3j1xkzTW8owIphkWV51V9s',
#   'duration_ms': 234341,
#   'time_signature': 4},
#  {'danceability': 0.801,
#   'energy': 0.601,
#   'key': 8,
#   'loudness': -7.574,
#   'mode': 0,
#   'speechiness': 0.255,
#   'acousticness': 0.0777,
#   'instrumentalness': 3.23e-05,
#   'liveness': 0.145,
#   'valence': 0.74,
#   'tempo': 159.969,
#   'type': 'audio_features',
#   'id': '0hquQWY3xvYqN4qtiquniF',
#   'uri': 'spotify:track:0hquQWY3xvYqN4qtiquniF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0hquQWY3xvYqN4qtiquniF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0hquQWY3xvYqN4qtiquniF',
#   'duration_ms': 182907,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.798,
#   'key': 1,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.034,
#   'instrumentalness': 4.19e-05,
#   'liveness': 0.0952,
#   'valence': 0.942,
#   'tempo': 116.032,
#   'type': 'audio_features',
#   'id': '6zSpb8dQRaw0M1dK8PBwQz',
#   'uri': 'spotify:track:6zSpb8dQRaw0M1dK8PBwQz',
#   'track_href': 'https://api.spotify.com/v1/tracks/6zSpb8dQRaw0M1dK8PBwQz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zSpb8dQRaw0M1dK8PBwQz',
#   'duration_ms': 202735,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.605,
#   'key': 4,
#   'loudness': -5.968,
#   'mode': 0,
#   'speechiness': 0.297,
#   'acousticness': 0.0336,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.145,
#   'tempo': 84.216,
#   'type': 'audio_features',
#   'id': '3ihIZrJreMJPjQdNLrEXnP',
#   'uri': 'spotify:track:3ihIZrJreMJPjQdNLrEXnP',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ihIZrJreMJPjQdNLrEXnP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ihIZrJreMJPjQdNLrEXnP',
#   'duration_ms': 200471,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.796,
#   'key': 5,
#   'loudness': -5.609,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.146,
#   'instrumentalness': 0,
#   'liveness': 0.125,
#   'valence': 0.53,
#   'tempo': 106.005,
#   'type': 'audio_features',
#   'id': '6AqwH2Y9FJwhUE2dCSkw1u',
#   'uri': 'spotify:track:6AqwH2Y9FJwhUE2dCSkw1u',
#   'track_href': 'https://api.spotify.com/v1/tracks/6AqwH2Y9FJwhUE2dCSkw1u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6AqwH2Y9FJwhUE2dCSkw1u',
#   'duration_ms': 189780,
#   'time_signature': 4},
#  {'danceability': 0.853,
#   'energy': 0.495,
#   'key': 6,
#   'loudness': -14.63,
#   'mode': 1,
#   'speechiness': 0.14,
#   'acousticness': 0.0917,
#   'instrumentalness': 0.000217,
#   'liveness': 0.0844,
#   'valence': 0.0774,
#   'tempo': 137.027,
#   'type': 'audio_features',
#   'id': '4rmVZajAF7PkrCagGPHbqa',
#   'uri': 'spotify:track:4rmVZajAF7PkrCagGPHbqa',
#   'track_href': 'https://api.spotify.com/v1/tracks/4rmVZajAF7PkrCagGPHbqa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4rmVZajAF7PkrCagGPHbqa',
#   'duration_ms': 243228,
#   'time_signature': 4},
#  {'danceability': 0.582,
#   'energy': 0.568,
#   'key': 1,
#   'loudness': -7.3,
#   'mode': 1,
#   'speechiness': 0.0275,
#   'acousticness': 0.577,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.394,
#   'tempo': 121.991,
#   'type': 'audio_features',
#   'id': '4686eQ81DEswHa90bcdlC9',
#   'uri': 'spotify:track:4686eQ81DEswHa90bcdlC9',
#   'track_href': 'https://api.spotify.com/v1/tracks/4686eQ81DEswHa90bcdlC9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4686eQ81DEswHa90bcdlC9',
#   'duration_ms': 207541,
#   'time_signature': 3},
#  {'danceability': 0.618,
#   'energy': 0.712,
#   'key': 1,
#   'loudness': -8.246,
#   'mode': 1,
#   'speechiness': 0.114,
#   'acousticness': 0.14,
#   'instrumentalness': 4.53e-06,
#   'liveness': 0.575,
#   'valence': 0.305,
#   'tempo': 97.057,
#   'type': 'audio_features',
#   'id': '6ufcuVInt0ocHrUimDjGlb',
#   'uri': 'spotify:track:6ufcuVInt0ocHrUimDjGlb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ufcuVInt0ocHrUimDjGlb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ufcuVInt0ocHrUimDjGlb',
#   'duration_ms': 254319,
#   'time_signature': 4},
#  {'danceability': 0.524,
#   'energy': 0.643,
#   'key': 9,
#   'loudness': -6.055,
#   'mode': 1,
#   'speechiness': 0.0297,
#   'acousticness': 0.451,
#   'instrumentalness': 0,
#   'liveness': 0.221,
#   'valence': 0.397,
#   'tempo': 135.962,
#   'type': 'audio_features',
#   'id': '5gVCfYmQRPy1QJifP8f5gg',
#   'uri': 'spotify:track:5gVCfYmQRPy1QJifP8f5gg',
#   'track_href': 'https://api.spotify.com/v1/tracks/5gVCfYmQRPy1QJifP8f5gg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gVCfYmQRPy1QJifP8f5gg',
#   'duration_ms': 232059,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.85,
#   'key': 11,
#   'loudness': -5.042,
#   'mode': 0,
#   'speechiness': 0.0699,
#   'acousticness': 0.0781,
#   'instrumentalness': 1.09e-06,
#   'liveness': 0.741,
#   'valence': 0.598,
#   'tempo': 107.988,
#   'type': 'audio_features',
#   'id': '0Fl4eWzVaMUOdXcOrj6F1q',
#   'uri': 'spotify:track:0Fl4eWzVaMUOdXcOrj6F1q',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Fl4eWzVaMUOdXcOrj6F1q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Fl4eWzVaMUOdXcOrj6F1q',
#   'duration_ms': 368758,
#   'time_signature': 4},
#  {'danceability': 0.87,
#   'energy': 0.516,
#   'key': 1,
#   'loudness': -8.006,
#   'mode': 1,
#   'speechiness': 0.0541,
#   'acousticness': 0.656,
#   'instrumentalness': 0.00823,
#   'liveness': 0.11,
#   'valence': 0.53,
#   'tempo': 111.005,
#   'type': 'audio_features',
#   'id': '7dSZ6zGTQx66c2GF91xCrb',
#   'uri': 'spotify:track:7dSZ6zGTQx66c2GF91xCrb',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dSZ6zGTQx66c2GF91xCrb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dSZ6zGTQx66c2GF91xCrb',
#   'duration_ms': 210200,
#   'time_signature': 4},
#  {'danceability': 0.369,
#   'energy': 0.192,
#   'key': 4,
#   'loudness': -12.151,
#   'mode': 0,
#   'speechiness': 0.04,
#   'acousticness': 0.555,
#   'instrumentalness': 8.35e-06,
#   'liveness': 0.0954,
#   'valence': 0.148,
#   'tempo': 175.212,
#   'type': 'audio_features',
#   'id': '3WMj8moIAXJhHsyLaqIIHI',
#   'uri': 'spotify:track:3WMj8moIAXJhHsyLaqIIHI',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WMj8moIAXJhHsyLaqIIHI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WMj8moIAXJhHsyLaqIIHI',
#   'duration_ms': 228013,
#   'time_signature': 3},
#  {'danceability': 0.801,
#   'energy': 0.475,
#   'key': 7,
#   'loudness': -8.797,
#   'mode': 0,
#   'speechiness': 0.0516,
#   'acousticness': 0.141,
#   'instrumentalness': 1.73e-05,
#   'liveness': 0.0639,
#   'valence': 0.234,
#   'tempo': 98.047,
#   'type': 'audio_features',
#   'id': '5Eax0qFko2dh7Rl2lYs3bx',
#   'uri': 'spotify:track:5Eax0qFko2dh7Rl2lYs3bx',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Eax0qFko2dh7Rl2lYs3bx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Eax0qFko2dh7Rl2lYs3bx',
#   'duration_ms': 213061,
#   'time_signature': 4},
#  {'danceability': 0.674,
#   'energy': 0.625,
#   'key': 1,
#   'loudness': -9.593,
#   'mode': 1,
#   'speechiness': 0.0514,
#   'acousticness': 0.0843,
#   'instrumentalness': 0.0015,
#   'liveness': 0.11,
#   'valence': 0.208,
#   'tempo': 120.004,
#   'type': 'audio_features',
#   'id': '3HyR1j49TY5ACP2lseF1jx',
#   'uri': 'spotify:track:3HyR1j49TY5ACP2lseF1jx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3HyR1j49TY5ACP2lseF1jx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HyR1j49TY5ACP2lseF1jx',
#   'duration_ms': 273998,
#   'time_signature': 4},
#  {'danceability': 0.825,
#   'energy': 0.414,
#   'key': 2,
#   'loudness': -6.634,
#   'mode': 1,
#   'speechiness': 0.144,
#   'acousticness': 0.00265,
#   'instrumentalness': 0,
#   'liveness': 0.357,
#   'valence': 0.106,
#   'tempo': 72.993,
#   'type': 'audio_features',
#   'id': '4A8cWXxKfIL3lAyUDzXbCF',
#   'uri': 'spotify:track:4A8cWXxKfIL3lAyUDzXbCF',
#   'track_href': 'https://api.spotify.com/v1/tracks/4A8cWXxKfIL3lAyUDzXbCF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4A8cWXxKfIL3lAyUDzXbCF',
#   'duration_ms': 200548,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.816,
#   'key': 6,
#   'loudness': -2.65,
#   'mode': 1,
#   'speechiness': 0.0269,
#   'acousticness': 0.00496,
#   'instrumentalness': 0,
#   'liveness': 0.179,
#   'valence': 0.865,
#   'tempo': 102.972,
#   'type': 'audio_features',
#   'id': '3SeeaIXnrCfT88vHVCRWHl',
#   'uri': 'spotify:track:3SeeaIXnrCfT88vHVCRWHl',
#   'track_href': 'https://api.spotify.com/v1/tracks/3SeeaIXnrCfT88vHVCRWHl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3SeeaIXnrCfT88vHVCRWHl',
#   'duration_ms': 181991,
#   'time_signature': 4},
#  {'danceability': 0.819,
#   'energy': 0.651,
#   'key': 1,
#   'loudness': -5.829,
#   'mode': 1,
#   'speechiness': 0.169,
#   'acousticness': 0.00639,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.501,
#   'tempo': 139.957,
#   'type': 'audio_features',
#   'id': '3GdWfmQBiiJrDUvSZS1bGv',
#   'uri': 'spotify:track:3GdWfmQBiiJrDUvSZS1bGv',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GdWfmQBiiJrDUvSZS1bGv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GdWfmQBiiJrDUvSZS1bGv',
#   'duration_ms': 185786,
#   'time_signature': 4},
#  {'danceability': 0.785,
#   'energy': 0.732,
#   'key': 1,
#   'loudness': -5.724,
#   'mode': 1,
#   'speechiness': 0.164,
#   'acousticness': 0.0636,
#   'instrumentalness': 0.000807,
#   'liveness': 0.265,
#   'valence': 0.496,
#   'tempo': 110.952,
#   'type': 'audio_features',
#   'id': '1w7cgGZR86yWz1pA2puVJD',
#   'uri': 'spotify:track:1w7cgGZR86yWz1pA2puVJD',
#   'track_href': 'https://api.spotify.com/v1/tracks/1w7cgGZR86yWz1pA2puVJD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1w7cgGZR86yWz1pA2puVJD',
#   'duration_ms': 260771,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.64,
#   'key': 4,
#   'loudness': -6.15,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.0512,
#   'instrumentalness': 5.52e-05,
#   'liveness': 0.0675,
#   'valence': 0.48,
#   'tempo': 144.022,
#   'type': 'audio_features',
#   'id': '4jp9FimhP2bQ93vR0A5r7b',
#   'uri': 'spotify:track:4jp9FimhP2bQ93vR0A5r7b',
#   'track_href': 'https://api.spotify.com/v1/tracks/4jp9FimhP2bQ93vR0A5r7b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jp9FimhP2bQ93vR0A5r7b',
#   'duration_ms': 230227,
#   'time_signature': 4},
#  {'danceability': 0.823,
#   'energy': 0.536,
#   'key': 5,
#   'loudness': -10.123,
#   'mode': 0,
#   'speechiness': 0.319,
#   'acousticness': 0.0616,
#   'instrumentalness': 0.0143,
#   'liveness': 0.326,
#   'valence': 0.537,
#   'tempo': 128.955,
#   'type': 'audio_features',
#   'id': '1LCm0lFnEsxR2oPqyHLGX9',
#   'uri': 'spotify:track:1LCm0lFnEsxR2oPqyHLGX9',
#   'track_href': 'https://api.spotify.com/v1/tracks/1LCm0lFnEsxR2oPqyHLGX9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1LCm0lFnEsxR2oPqyHLGX9',
#   'duration_ms': 244792,
#   'time_signature': 4},
#  {'danceability': 0.559,
#   'energy': 0.66,
#   'key': 7,
#   'loudness': -4.143,
#   'mode': 1,
#   'speechiness': 0.0512,
#   'acousticness': 0.222,
#   'instrumentalness': 0,
#   'liveness': 0.193,
#   'valence': 0.574,
#   'tempo': 163.957,
#   'type': 'audio_features',
#   'id': '2afB4eV1KWBqLqFqME6PTh',
#   'uri': 'spotify:track:2afB4eV1KWBqLqFqME6PTh',
#   'track_href': 'https://api.spotify.com/v1/tracks/2afB4eV1KWBqLqFqME6PTh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2afB4eV1KWBqLqFqME6PTh',
#   'duration_ms': 157907,
#   'time_signature': 4},
#  {'danceability': 0.876,
#   'energy': 0.628,
#   'key': 1,
#   'loudness': -6.595,
#   'mode': 1,
#   'speechiness': 0.0935,
#   'acousticness': 0.0165,
#   'instrumentalness': 0.0339,
#   'liveness': 0.0938,
#   'valence': 0.809,
#   'tempo': 118.028,
#   'type': 'audio_features',
#   'id': '5YLGlPYkZBDXieMwzVve7g',
#   'uri': 'spotify:track:5YLGlPYkZBDXieMwzVve7g',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YLGlPYkZBDXieMwzVve7g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YLGlPYkZBDXieMwzVve7g',
#   'duration_ms': 203383,
#   'time_signature': 4},
#  {'danceability': 0.878,
#   'energy': 0.685,
#   'key': 9,
#   'loudness': -5.28,
#   'mode': 1,
#   'speechiness': 0.225,
#   'acousticness': 0.00152,
#   'instrumentalness': 0,
#   'liveness': 0.0753,
#   'valence': 0.523,
#   'tempo': 157.003,
#   'type': 'audio_features',
#   'id': '3uJFmluXzYedoJcvhpC1AW',
#   'uri': 'spotify:track:3uJFmluXzYedoJcvhpC1AW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3uJFmluXzYedoJcvhpC1AW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3uJFmluXzYedoJcvhpC1AW',
#   'duration_ms': 211649,
#   'time_signature': 4},
#  {'danceability': 0.899,
#   'energy': 0.464,
#   'key': 2,
#   'loudness': -8.003,
#   'mode': 1,
#   'speechiness': 0.0667,
#   'acousticness': 0.504,
#   'instrumentalness': 0.9,
#   'liveness': 0.0753,
#   'valence': 0.654,
#   'tempo': 101.014,
#   'type': 'audio_features',
#   'id': '3QRJgF8HY4zEuboEy4Q1gd',
#   'uri': 'spotify:track:3QRJgF8HY4zEuboEy4Q1gd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QRJgF8HY4zEuboEy4Q1gd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QRJgF8HY4zEuboEy4Q1gd',
#   'duration_ms': 152117,
#   'time_signature': 4},
#  {'danceability': 0.365,
#   'energy': 0.541,
#   'key': 7,
#   'loudness': -7.489,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.0419,
#   'instrumentalness': 2.25e-06,
#   'liveness': 0.281,
#   'valence': 0.329,
#   'tempo': 86.041,
#   'type': 'audio_features',
#   'id': '25VQoiuyc0HkC5FQTj1a8G',
#   'uri': 'spotify:track:25VQoiuyc0HkC5FQTj1a8G',
#   'track_href': 'https://api.spotify.com/v1/tracks/25VQoiuyc0HkC5FQTj1a8G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25VQoiuyc0HkC5FQTj1a8G',
#   'duration_ms': 232093,
#   'time_signature': 4},
#  {'danceability': 0.829,
#   'energy': 0.799,
#   'key': 9,
#   'loudness': -5.389,
#   'mode': 1,
#   'speechiness': 0.0897,
#   'acousticness': 0.0151,
#   'instrumentalness': 0.000543,
#   'liveness': 0.242,
#   'valence': 0.471,
#   'tempo': 97.013,
#   'type': 'audio_features',
#   'id': '4tYFy8ALRjIZvnvSLw5lxN',
#   'uri': 'spotify:track:4tYFy8ALRjIZvnvSLw5lxN',
#   'track_href': 'https://api.spotify.com/v1/tracks/4tYFy8ALRjIZvnvSLw5lxN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4tYFy8ALRjIZvnvSLw5lxN',
#   'duration_ms': 227629,
#   'time_signature': 4},
#  {'danceability': 0.869,
#   'energy': 0.298,
#   'key': 2,
#   'loudness': -12.076,
#   'mode': 1,
#   'speechiness': 0.386,
#   'acousticness': 0.2,
#   'instrumentalness': 0,
#   'liveness': 0.0753,
#   'valence': 0.178,
#   'tempo': 77.47,
#   'type': 'audio_features',
#   'id': '5cx7vkF8BQ0iOsVpfvZbnz',
#   'uri': 'spotify:track:5cx7vkF8BQ0iOsVpfvZbnz',
#   'track_href': 'https://api.spotify.com/v1/tracks/5cx7vkF8BQ0iOsVpfvZbnz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cx7vkF8BQ0iOsVpfvZbnz',
#   'duration_ms': 161355,
#   'time_signature': 4},
#  {'danceability': 0.647,
#   'energy': 0.686,
#   'key': 3,
#   'loudness': -5.745,
#   'mode': 0,
#   'speechiness': 0.0413,
#   'acousticness': 0.08,
#   'instrumentalness': 1.34e-06,
#   'liveness': 0.528,
#   'valence': 0.268,
#   'tempo': 79.928,
#   'type': 'audio_features',
#   'id': '3k3NWokhRRkEPhCzPmV8TW',
#   'uri': 'spotify:track:3k3NWokhRRkEPhCzPmV8TW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3k3NWokhRRkEPhCzPmV8TW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3k3NWokhRRkEPhCzPmV8TW',
#   'duration_ms': 258299,
#   'time_signature': 4},
#  {'danceability': 0.864,
#   'energy': 0.476,
#   'key': 1,
#   'loudness': -10.068,
#   'mode': 1,
#   'speechiness': 0.436,
#   'acousticness': 0.0374,
#   'instrumentalness': 0,
#   'liveness': 0.374,
#   'valence': 0.647,
#   'tempo': 157.144,
#   'type': 'audio_features',
#   'id': '1vrFJDrysqmsNAgyjBzx4f',
#   'uri': 'spotify:track:1vrFJDrysqmsNAgyjBzx4f',
#   'track_href': 'https://api.spotify.com/v1/tracks/1vrFJDrysqmsNAgyjBzx4f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1vrFJDrysqmsNAgyjBzx4f',
#   'duration_ms': 137580,
#   'time_signature': 4},
#  {'danceability': 0.912,
#   'energy': 0.774,
#   'key': 0,
#   'loudness': -4.673,
#   'mode': 0,
#   'speechiness': 0.0455,
#   'acousticness': 0.121,
#   'instrumentalness': 0.0127,
#   'liveness': 0.101,
#   'valence': 0.632,
#   'tempo': 119.966,
#   'type': 'audio_features',
#   'id': '10xV5l9nhLvFpR8mqzs0bL',
#   'uri': 'spotify:track:10xV5l9nhLvFpR8mqzs0bL',
#   'track_href': 'https://api.spotify.com/v1/tracks/10xV5l9nhLvFpR8mqzs0bL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10xV5l9nhLvFpR8mqzs0bL',
#   'duration_ms': 155589,
#   'time_signature': 4},
#  {'danceability': 0.857,
#   'energy': 0.558,
#   'key': 1,
#   'loudness': -7.888,
#   'mode': 1,
#   'speechiness': 0.134,
#   'acousticness': 0.0122,
#   'instrumentalness': 4.8e-05,
#   'liveness': 0.288,
#   'valence': 0.453,
#   'tempo': 123.973,
#   'type': 'audio_features',
#   'id': '4DByEumlGTZKSzuVEZ35eo',
#   'uri': 'spotify:track:4DByEumlGTZKSzuVEZ35eo',
#   'track_href': 'https://api.spotify.com/v1/tracks/4DByEumlGTZKSzuVEZ35eo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DByEumlGTZKSzuVEZ35eo',
#   'duration_ms': 288255,
#   'time_signature': 4},
#  {'danceability': 0.723,
#   'energy': 0.772,
#   'key': 1,
#   'loudness': -6.784,
#   'mode': 1,
#   'speechiness': 0.0792,
#   'acousticness': 0.00524,
#   'instrumentalness': 1.15e-05,
#   'liveness': 0.367,
#   'valence': 0.58,
#   'tempo': 102.004,
#   'type': 'audio_features',
#   'id': '4cacyP5c3PMlfnyjpg13xW',
#   'uri': 'spotify:track:4cacyP5c3PMlfnyjpg13xW',
#   'track_href': 'https://api.spotify.com/v1/tracks/4cacyP5c3PMlfnyjpg13xW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4cacyP5c3PMlfnyjpg13xW',
#   'duration_ms': 146471,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.755,
#   'key': 1,
#   'loudness': -5.864,
#   'mode': 1,
#   'speechiness': 0.125,
#   'acousticness': 0.222,
#   'instrumentalness': 0,
#   'liveness': 0.0986,
#   'valence': 0.528,
#   'tempo': 96.86,
#   'type': 'audio_features',
#   'id': '4MDYIbU6I29Gjiu7JATTIJ',
#   'uri': 'spotify:track:4MDYIbU6I29Gjiu7JATTIJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4MDYIbU6I29Gjiu7JATTIJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4MDYIbU6I29Gjiu7JATTIJ',
#   'duration_ms': 174360,
#   'time_signature': 4},
#  {'danceability': 0.564,
#   'energy': 0.903,
#   'key': 5,
#   'loudness': -3.221,
#   'mode': 1,
#   'speechiness': 0.307,
#   'acousticness': 0.356,
#   'instrumentalness': 0,
#   'liveness': 0.175,
#   'valence': 0.607,
#   'tempo': 78.293,
#   'type': 'audio_features',
#   'id': '1dm6z1fWB0cErMszU25dy2',
#   'uri': 'spotify:track:1dm6z1fWB0cErMszU25dy2',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dm6z1fWB0cErMszU25dy2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dm6z1fWB0cErMszU25dy2',
#   'duration_ms': 230400,
#   'time_signature': 4},
#  {'danceability': 0.576,
#   'energy': 0.627,
#   'key': 3,
#   'loudness': -4.649,
#   'mode': 0,
#   'speechiness': 0.0449,
#   'acousticness': 0.0385,
#   'instrumentalness': 0,
#   'liveness': 0.181,
#   'valence': 0.311,
#   'tempo': 164.998,
#   'type': 'audio_features',
#   'id': '6kxaaIeowajN7w21PfMLbu',
#   'uri': 'spotify:track:6kxaaIeowajN7w21PfMLbu',
#   'track_href': 'https://api.spotify.com/v1/tracks/6kxaaIeowajN7w21PfMLbu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6kxaaIeowajN7w21PfMLbu',
#   'duration_ms': 176059,
#   'time_signature': 4},
#  {'danceability': 0.789,
#   'energy': 0.614,
#   'key': 1,
#   'loudness': -6.491,
#   'mode': 1,
#   'speechiness': 0.0579,
#   'acousticness': 0.00348,
#   'instrumentalness': 0.00152,
#   'liveness': 0.283,
#   'valence': 0.108,
#   'tempo': 126.035,
#   'type': 'audio_features',
#   'id': '2XMAWynSTIst5KmLSv0Npf',
#   'uri': 'spotify:track:2XMAWynSTIst5KmLSv0Npf',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XMAWynSTIst5KmLSv0Npf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XMAWynSTIst5KmLSv0Npf',
#   'duration_ms': 198898,
#   'time_signature': 4},
#  {'danceability': 0.744,
#   'energy': 0.577,
#   'key': 9,
#   'loudness': -7.228,
#   'mode': 1,
#   'speechiness': 0.0631,
#   'acousticness': 0.0672,
#   'instrumentalness': 3.06e-06,
#   'liveness': 0.178,
#   'valence': 0.0805,
#   'tempo': 135.869,
#   'type': 'audio_features',
#   'id': '3k4CoiIQXiNBrwrmbBMDxj',
#   'uri': 'spotify:track:3k4CoiIQXiNBrwrmbBMDxj',
#   'track_href': 'https://api.spotify.com/v1/tracks/3k4CoiIQXiNBrwrmbBMDxj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3k4CoiIQXiNBrwrmbBMDxj',
#   'duration_ms': 169820,
#   'time_signature': 4},
#  {'danceability': 0.678,
#   'energy': 0.528,
#   'key': 10,
#   'loudness': -7.317,
#   'mode': 1,
#   'speechiness': 0.0551,
#   'acousticness': 0.289,
#   'instrumentalness': 0,
#   'liveness': 0.0734,
#   'valence': 0.614,
#   'tempo': 79.018,
#   'type': 'audio_features',
#   'id': '3HGnIIdHYIbkowzLk8UHbE',
#   'uri': 'spotify:track:3HGnIIdHYIbkowzLk8UHbE',
#   'track_href': 'https://api.spotify.com/v1/tracks/3HGnIIdHYIbkowzLk8UHbE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HGnIIdHYIbkowzLk8UHbE',
#   'duration_ms': 194545,
#   'time_signature': 4},
#  {'danceability': 0.582,
#   'energy': 0.797,
#   'key': 5,
#   'loudness': -4.926,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.23,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.595,
#   'tempo': 135.973,
#   'type': 'audio_features',
#   'id': '4lSNyiHil3tuiwtvEpN1qq',
#   'uri': 'spotify:track:4lSNyiHil3tuiwtvEpN1qq',
#   'track_href': 'https://api.spotify.com/v1/tracks/4lSNyiHil3tuiwtvEpN1qq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4lSNyiHil3tuiwtvEpN1qq',
#   'duration_ms': 196027,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.773,
#   'key': 0,
#   'loudness': -5.619,
#   'mode': 1,
#   'speechiness': 0.153,
#   'acousticness': 0.038,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.377,
#   'tempo': 93.923,
#   'type': 'audio_features',
#   'id': '32vE1nuG8T9c8bhmZdRY6d',
#   'uri': 'spotify:track:32vE1nuG8T9c8bhmZdRY6d',
#   'track_href': 'https://api.spotify.com/v1/tracks/32vE1nuG8T9c8bhmZdRY6d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/32vE1nuG8T9c8bhmZdRY6d',
#   'duration_ms': 185857,
#   'time_signature': 4},
#  {'danceability': 0.795,
#   'energy': 0.684,
#   'key': 11,
#   'loudness': -3.971,
#   'mode': 0,
#   'speechiness': 0.0419,
#   'acousticness': 0.0225,
#   'instrumentalness': 0,
#   'liveness': 0.658,
#   'valence': 0.419,
#   'tempo': 114.011,
#   'type': 'audio_features',
#   'id': '41oY4WCTj5kccfesTVFnvN',
#   'uri': 'spotify:track:41oY4WCTj5kccfesTVFnvN',
#   'track_href': 'https://api.spotify.com/v1/tracks/41oY4WCTj5kccfesTVFnvN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/41oY4WCTj5kccfesTVFnvN',
#   'duration_ms': 237895,
#   'time_signature': 4},
#  {'danceability': 0.795,
#   'energy': 0.565,
#   'key': 3,
#   'loudness': -4.457,
#   'mode': 0,
#   'speechiness': 0.0948,
#   'acousticness': 0.131,
#   'instrumentalness': 0,
#   'liveness': 0.0802,
#   'valence': 0.55,
#   'tempo': 87.925,
#   'type': 'audio_features',
#   'id': '2PDgArI0p7UkeYgXWuqpmh',
#   'uri': 'spotify:track:2PDgArI0p7UkeYgXWuqpmh',
#   'track_href': 'https://api.spotify.com/v1/tracks/2PDgArI0p7UkeYgXWuqpmh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PDgArI0p7UkeYgXWuqpmh',
#   'duration_ms': 172342,
#   'time_signature': 4},
#  {'danceability': 0.504,
#   'energy': 0.736,
#   'key': 0,
#   'loudness': -6.079,
#   'mode': 1,
#   'speechiness': 0.0352,
#   'acousticness': 0.00216,
#   'instrumentalness': 0,
#   'liveness': 0.129,
#   'valence': 0.46,
#   'tempo': 148.014,
#   'type': 'audio_features',
#   'id': '4RG7P0CXQ4pe0OeCAHjX5L',
#   'uri': 'spotify:track:4RG7P0CXQ4pe0OeCAHjX5L',
#   'track_href': 'https://api.spotify.com/v1/tracks/4RG7P0CXQ4pe0OeCAHjX5L',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RG7P0CXQ4pe0OeCAHjX5L',
#   'duration_ms': 199733,
#   'time_signature': 4},
#  {'danceability': 0.562,
#   'energy': 0.463,
#   'key': 6,
#   'loudness': -7.478,
#   'mode': 1,
#   'speechiness': 0.0787,
#   'acousticness': 0.442,
#   'instrumentalness': 0.000145,
#   'liveness': 0.157,
#   'valence': 0.416,
#   'tempo': 125.15,
#   'type': 'audio_features',
#   'id': '2mzM4Y0Rnx2BDZqRnhQ5Q6',
#   'uri': 'spotify:track:2mzM4Y0Rnx2BDZqRnhQ5Q6',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mzM4Y0Rnx2BDZqRnhQ5Q6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mzM4Y0Rnx2BDZqRnhQ5Q6',
#   'duration_ms': 247579,
#   'time_signature': 5},
#  {'danceability': 0.468,
#   'energy': 0.779,
#   'key': 9,
#   'loudness': -4.839,
#   'mode': 1,
#   'speechiness': 0.0779,
#   'acousticness': 0.112,
#   'instrumentalness': 0.000373,
#   'liveness': 0.101,
#   'valence': 0.26,
#   'tempo': 173.799,
#   'type': 'audio_features',
#   'id': '1yvMUkIOTeUNtNWlWRgANS',
#   'uri': 'spotify:track:1yvMUkIOTeUNtNWlWRgANS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yvMUkIOTeUNtNWlWRgANS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yvMUkIOTeUNtNWlWRgANS',
#   'duration_ms': 217747,
#   'time_signature': 4},
#  {'danceability': 0.883,
#   'energy': 0.657,
#   'key': 8,
#   'loudness': -5.748,
#   'mode': 1,
#   'speechiness': 0.305,
#   'acousticness': 0.0603,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.284,
#   'tempo': 124.992,
#   'type': 'audio_features',
#   'id': '1qMMYpVatbRITKCfq1gasi',
#   'uri': 'spotify:track:1qMMYpVatbRITKCfq1gasi',
#   'track_href': 'https://api.spotify.com/v1/tracks/1qMMYpVatbRITKCfq1gasi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qMMYpVatbRITKCfq1gasi',
#   'duration_ms': 172933,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.708,
#   'key': 10,
#   'loudness': -4.639,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.0975,
#   'instrumentalness': 0,
#   'liveness': 0.12,
#   'valence': 0.697,
#   'tempo': 161.989,
#   'type': 'audio_features',
#   'id': '4Qum1kECNQrpREev5fvAQ4',
#   'uri': 'spotify:track:4Qum1kECNQrpREev5fvAQ4',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Qum1kECNQrpREev5fvAQ4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Qum1kECNQrpREev5fvAQ4',
#   'duration_ms': 203037,
#   'time_signature': 4},
#  {'danceability': 0.479,
#   'energy': 0.768,
#   'key': 8,
#   'loudness': -5.204,
#   'mode': 1,
#   'speechiness': 0.0312,
#   'acousticness': 7.02e-05,
#   'instrumentalness': 0.00549,
#   'liveness': 0.121,
#   'valence': 0.576,
#   'tempo': 110.024,
#   'type': 'audio_features',
#   'id': '6Tm4Io4ct4w14nB1EUzsY3',
#   'uri': 'spotify:track:6Tm4Io4ct4w14nB1EUzsY3',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Tm4Io4ct4w14nB1EUzsY3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Tm4Io4ct4w14nB1EUzsY3',
#   'duration_ms': 183790,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.756,
#   'key': 7,
#   'loudness': -4.483,
#   'mode': 1,
#   'speechiness': 0.0288,
#   'acousticness': 0.0587,
#   'instrumentalness': 0,
#   'liveness': 0.378,
#   'valence': 0.596,
#   'tempo': 106.012,
#   'type': 'audio_features',
#   'id': '20WKHeDTmtU0Zj4sNB8aoA',
#   'uri': 'spotify:track:20WKHeDTmtU0Zj4sNB8aoA',
#   'track_href': 'https://api.spotify.com/v1/tracks/20WKHeDTmtU0Zj4sNB8aoA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20WKHeDTmtU0Zj4sNB8aoA',
#   'duration_ms': 167376,
#   'time_signature': 4},
#  {'danceability': 0.586,
#   'energy': 0.556,
#   'key': 6,
#   'loudness': -7.639,
#   'mode': 1,
#   'speechiness': 0.0592,
#   'acousticness': 0.00655,
#   'instrumentalness': 0,
#   'liveness': 0.0836,
#   'valence': 0.517,
#   'tempo': 167.018,
#   'type': 'audio_features',
#   'id': '4svaKoxMMP7ImmKrD5hfQu',
#   'uri': 'spotify:track:4svaKoxMMP7ImmKrD5hfQu',
#   'track_href': 'https://api.spotify.com/v1/tracks/4svaKoxMMP7ImmKrD5hfQu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4svaKoxMMP7ImmKrD5hfQu',
#   'duration_ms': 176125,
#   'time_signature': 4},
#  {'danceability': 0.773,
#   'energy': 0.742,
#   'key': 5,
#   'loudness': -3.678,
#   'mode': 0,
#   'speechiness': 0.046,
#   'acousticness': 0.0206,
#   'instrumentalness': 0,
#   'liveness': 0.0754,
#   'valence': 0.571,
#   'tempo': 114.071,
#   'type': 'audio_features',
#   'id': '0HqZX76SFLDz2aW8aiqi7G',
#   'uri': 'spotify:track:0HqZX76SFLDz2aW8aiqi7G',
#   'track_href': 'https://api.spotify.com/v1/tracks/0HqZX76SFLDz2aW8aiqi7G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HqZX76SFLDz2aW8aiqi7G',
#   'duration_ms': 165265,
#   'time_signature': 4},
#  {'danceability': 0.79,
#   'energy': 0.325,
#   'key': 4,
#   'loudness': -11.689,
#   'mode': 1,
#   'speechiness': 0.127,
#   'acousticness': 0.509,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.539,
#   'tempo': 126.877,
#   'type': 'audio_features',
#   'id': '6VVqPBFZIbcmv14zNfOc13',
#   'uri': 'spotify:track:6VVqPBFZIbcmv14zNfOc13',
#   'track_href': 'https://api.spotify.com/v1/tracks/6VVqPBFZIbcmv14zNfOc13',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6VVqPBFZIbcmv14zNfOc13',
#   'duration_ms': 163311,
#   'time_signature': 4},
#  {'danceability': 0.494,
#   'energy': 0.782,
#   'key': 3,
#   'loudness': -4.228,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.0443,
#   'instrumentalness': 0,
#   'liveness': 0.0921,
#   'valence': 0.44,
#   'tempo': 75.932,
#   'type': 'audio_features',
#   'id': '2NYOqKy4VX6dqVtzrv1Cx9',
#   'uri': 'spotify:track:2NYOqKy4VX6dqVtzrv1Cx9',
#   'track_href': 'https://api.spotify.com/v1/tracks/2NYOqKy4VX6dqVtzrv1Cx9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NYOqKy4VX6dqVtzrv1Cx9',
#   'duration_ms': 186373,
#   'time_signature': 4},
#  {'danceability': 0.821,
#   'energy': 0.636,
#   'key': 11,
#   'loudness': -4.479,
#   'mode': 1,
#   'speechiness': 0.169,
#   'acousticness': 0.142,
#   'instrumentalness': 0,
#   'liveness': 0.233,
#   'valence': 0.163,
#   'tempo': 127.961,
#   'type': 'audio_features',
#   'id': '0QNNd0qMCDbraS1nQPg3aA',
#   'uri': 'spotify:track:0QNNd0qMCDbraS1nQPg3aA',
#   'track_href': 'https://api.spotify.com/v1/tracks/0QNNd0qMCDbraS1nQPg3aA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0QNNd0qMCDbraS1nQPg3aA',
#   'duration_ms': 142657,
#   'time_signature': 4},
#  {'danceability': 0.472,
#   'energy': 0.701,
#   'key': 2,
#   'loudness': -4.563,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.0387,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.515,
#   'tempo': 79.805,
#   'type': 'audio_features',
#   'id': '7xNYZeFtrB05pi9tc6lEeb',
#   'uri': 'spotify:track:7xNYZeFtrB05pi9tc6lEeb',
#   'track_href': 'https://api.spotify.com/v1/tracks/7xNYZeFtrB05pi9tc6lEeb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xNYZeFtrB05pi9tc6lEeb',
#   'duration_ms': 169440,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.373,
#   'key': 11,
#   'loudness': -10.234,
#   'mode': 1,
#   'speechiness': 0.595,
#   'acousticness': 0.149,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.35,
#   'tempo': 167.912,
#   'type': 'audio_features',
#   'id': '2TSfStvlAMLw89u3tali79',
#   'uri': 'spotify:track:2TSfStvlAMLw89u3tali79',
#   'track_href': 'https://api.spotify.com/v1/tracks/2TSfStvlAMLw89u3tali79',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TSfStvlAMLw89u3tali79',
#   'duration_ms': 151776,
#   'time_signature': 4},
#  {'danceability': 0.376,
#   'energy': 0.657,
#   'key': 7,
#   'loudness': -4.658,
#   'mode': 1,
#   'speechiness': 0.0768,
#   'acousticness': 0.0858,
#   'instrumentalness': 0,
#   'liveness': 0.0884,
#   'valence': 0.203,
#   'tempo': 80.565,
#   'type': 'audio_features',
#   'id': '1r8ZCjfrQxoy2wVaBUbpwg',
#   'uri': 'spotify:track:1r8ZCjfrQxoy2wVaBUbpwg',
#   'track_href': 'https://api.spotify.com/v1/tracks/1r8ZCjfrQxoy2wVaBUbpwg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1r8ZCjfrQxoy2wVaBUbpwg',
#   'duration_ms': 164782,
#   'time_signature': 4},
#  {'danceability': 0.479,
#   'energy': 0.742,
#   'key': 7,
#   'loudness': -5.587,
#   'mode': 1,
#   'speechiness': 0.0539,
#   'acousticness': 0.0069,
#   'instrumentalness': 0.000834,
#   'liveness': 0.278,
#   'valence': 0.454,
#   'tempo': 142.909,
#   'type': 'audio_features',
#   'id': '2FGOg7uYBfnspkPOISXTFY',
#   'uri': 'spotify:track:2FGOg7uYBfnspkPOISXTFY',
#   'track_href': 'https://api.spotify.com/v1/tracks/2FGOg7uYBfnspkPOISXTFY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2FGOg7uYBfnspkPOISXTFY',
#   'duration_ms': 181400,
#   'time_signature': 3},
#  {'danceability': 0.791,
#   'energy': 0.439,
#   'key': 10,
#   'loudness': -5.62,
#   'mode': 1,
#   'speechiness': 0.0645,
#   'acousticness': 0.302,
#   'instrumentalness': 1.85e-05,
#   'liveness': 0.126,
#   'valence': 0.559,
#   'tempo': 85.004,
#   'type': 'audio_features',
#   'id': '16MQETUgqXwY4lZcyRafU3',
#   'uri': 'spotify:track:16MQETUgqXwY4lZcyRafU3',
#   'track_href': 'https://api.spotify.com/v1/tracks/16MQETUgqXwY4lZcyRafU3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16MQETUgqXwY4lZcyRafU3',
#   'duration_ms': 190659,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.695,
#   'key': 6,
#   'loudness': -6.174,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.488,
#   'instrumentalness': 1.24e-05,
#   'liveness': 0.142,
#   'valence': 0.514,
#   'tempo': 139.993,
#   'type': 'audio_features',
#   'id': '6NHpyYvJyQsg2nXXzGYc2R',
#   'uri': 'spotify:track:6NHpyYvJyQsg2nXXzGYc2R',
#   'track_href': 'https://api.spotify.com/v1/tracks/6NHpyYvJyQsg2nXXzGYc2R',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NHpyYvJyQsg2nXXzGYc2R',
#   'duration_ms': 215572,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.643,
#   'key': 4,
#   'loudness': -5.867,
#   'mode': 0,
#   'speechiness': 0.0828,
#   'acousticness': 0.138,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.477,
#   'tempo': 95.055,
#   'type': 'audio_features',
#   'id': '2UN0lp72LAusrXi8LLVomt',
#   'uri': 'spotify:track:2UN0lp72LAusrXi8LLVomt',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UN0lp72LAusrXi8LLVomt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UN0lp72LAusrXi8LLVomt',
#   'duration_ms': 163450,
#   'time_signature': 4},
#  {'danceability': 0.499,
#   'energy': 0.671,
#   'key': 4,
#   'loudness': -6.774,
#   'mode': 0,
#   'speechiness': 0.0561,
#   'acousticness': 0.114,
#   'instrumentalness': 0.0169,
#   'liveness': 0.148,
#   'valence': 0.0557,
#   'tempo': 124.994,
#   'type': 'audio_features',
#   'id': '28JBD8p18xNuOfyV7Cotdn',
#   'uri': 'spotify:track:28JBD8p18xNuOfyV7Cotdn',
#   'track_href': 'https://api.spotify.com/v1/tracks/28JBD8p18xNuOfyV7Cotdn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/28JBD8p18xNuOfyV7Cotdn',
#   'duration_ms': 336924,
#   'time_signature': 3},
#  {'danceability': 0.539,
#   'energy': 0.508,
#   'key': 10,
#   'loudness': -6.05,
#   'mode': 1,
#   'speechiness': 0.0288,
#   'acousticness': 0.727,
#   'instrumentalness': 0,
#   'liveness': 0.174,
#   'valence': 0.227,
#   'tempo': 101.358,
#   'type': 'audio_features',
#   'id': '0T5iIrXA4p5GsubkhuBIKV',
#   'uri': 'spotify:track:0T5iIrXA4p5GsubkhuBIKV',
#   'track_href': 'https://api.spotify.com/v1/tracks/0T5iIrXA4p5GsubkhuBIKV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0T5iIrXA4p5GsubkhuBIKV',
#   'duration_ms': 177720,
#   'time_signature': 3},
#  {'danceability': 0.787,
#   'energy': 0.546,
#   'key': 0,
#   'loudness': -7.094,
#   'mode': 0,
#   'speechiness': 0.0532,
#   'acousticness': 0.305,
#   'instrumentalness': 4.55e-05,
#   'liveness': 0.122,
#   'valence': 0.222,
#   'tempo': 93.05,
#   'type': 'audio_features',
#   'id': '5CzixCxDkRXX9mScCmah8O',
#   'uri': 'spotify:track:5CzixCxDkRXX9mScCmah8O',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CzixCxDkRXX9mScCmah8O',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CzixCxDkRXX9mScCmah8O',
#   'duration_ms': 176936,
#   'time_signature': 4},
#  {'danceability': 0.512,
#   'energy': 0.841,
#   'key': 7,
#   'loudness': -3.8,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.0424,
#   'instrumentalness': 0.000257,
#   'liveness': 0.113,
#   'valence': 0.33,
#   'tempo': 156.077,
#   'type': 'audio_features',
#   'id': '0R1REdJZIDy7IS3DybdBce',
#   'uri': 'spotify:track:0R1REdJZIDy7IS3DybdBce',
#   'track_href': 'https://api.spotify.com/v1/tracks/0R1REdJZIDy7IS3DybdBce',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0R1REdJZIDy7IS3DybdBce',
#   'duration_ms': 187433,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.786,
#   'key': 11,
#   'loudness': -3.51,
#   'mode': 0,
#   'speechiness': 0.195,
#   'acousticness': 0.229,
#   'instrumentalness': 0,
#   'liveness': 0.219,
#   'valence': 0.579,
#   'tempo': 196.12,
#   'type': 'audio_features',
#   'id': '1797zYiX4cKosMH836X9Gt',
#   'uri': 'spotify:track:1797zYiX4cKosMH836X9Gt',
#   'track_href': 'https://api.spotify.com/v1/tracks/1797zYiX4cKosMH836X9Gt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1797zYiX4cKosMH836X9Gt',
#   'duration_ms': 198367,
#   'time_signature': 4},
#  {'danceability': 0.621,
#   'energy': 0.782,
#   'key': 2,
#   'loudness': -5.548,
#   'mode': 1,
#   'speechiness': 0.044,
#   'acousticness': 0.0125,
#   'instrumentalness': 0.033,
#   'liveness': 0.23,
#   'valence': 0.55,
#   'tempo': 128.033,
#   'type': 'audio_features',
#   'id': '2tTmW7RDtMQtBk7m2rYeSw',
#   'uri': 'spotify:track:2tTmW7RDtMQtBk7m2rYeSw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tTmW7RDtMQtBk7m2rYeSw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tTmW7RDtMQtBk7m2rYeSw',
#   'duration_ms': 198938,
#   'time_signature': 4}]

# %%
audio_fea=pd.DataFrame(audio).reset_index()
audio_fea=audio_fea.drop(columns=['type','uri','track_href','analysis_url'])
audio_fea=audio_fea.rename(columns={'id':'track_uri'})
audio_fea
# Out:
#     index  danceability  energy  key  loudness  mode  speechiness  \
# 0       0         0.687   0.887    1    -5.040     0       0.0826
# 1       1         0.836   0.743   10    -6.305     0       0.0656
# 2       2         0.520   0.731    6    -5.338     0       0.0557
# 3       3         0.625   0.533   10   -11.903     0       0.0596
# 4       4         0.463   0.642    1    -4.474     1       0.3400
# ..    ...           ...     ...  ...       ...   ...          ...
# 95     95         0.539   0.508   10    -6.050     1       0.0288
# 96     96         0.787   0.546    0    -7.094     0       0.0532
# 97     97         0.512   0.841    7    -3.800     1       0.0309
# 98     98         0.663   0.786   11    -3.510     0       0.1950
# 99     99         0.621   0.782    2    -5.548     1       0.0440
#
#     acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0575          0.000002    0.2700    0.853  114.941
# 1         0.0995          0.000000    0.3350    0.722  108.966
# 2         0.3420          0.001010    0.3110    0.662  173.930
# 3         0.6590          0.002660    0.0546    0.139  108.296
# 4         0.3140          0.000000    0.0686    0.339   83.389
# ..           ...               ...       ...      ...      ...
# 95        0.7270          0.000000    0.1740    0.227  101.358
# 96        0.3050          0.000046    0.1220    0.222   93.050
# 97        0.0424          0.000257    0.1130    0.330  156.077
# 98        0.2290          0.000000    0.2190    0.579  196.120
# 99        0.0125          0.033000    0.2300    0.550  128.033
#
#                  track_uri  duration_ms  time_signature
# 0   2KukL7UlQ8TdvpaA7bY3ZJ       278282               4
# 1   1PckUlxKqWQs3RlWXVBLw3       191822               4
# 2   4LRPiXqCikLlN15c3yImP7       167303               4
# 3   29d0nY7TzCoi22XBqDQkiP       300840               4
# 4   59nOXPmaKlBfGMDeOVGrIK       189893               4
# ..                     ...          ...             ...
# 95  0T5iIrXA4p5GsubkhuBIKV       177720               3
# 96  5CzixCxDkRXX9mScCmah8O       176936               4
# 97  0R1REdJZIDy7IS3DybdBce       187433               4
# 98  1797zYiX4cKosMH836X9Gt       198367               4
# 99  2tTmW7RDtMQtBk7m2rYeSw       198938               4
#
# [100 rows x 15 columns]

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)
        artist_genres = artist_info["genres"]
        result = artist_genres
        tracks.append(result)

    return tracks


track_genres = get_tracks()

# %%
genres=pd.DataFrame(track_genres)
genres=genres.rename(columns={0:'primary_genre',1:'sub_genre_1', 2:'sub_genre_2'})
genres= genres[['primary_genre','sub_genre_1','sub_genre_2']].reset_index()
genres
# Out:
#     index            primary_genre     sub_genre_1        sub_genre_2
# 0       0                dance pop             pop                r&b
# 1       1                dance pop     escape room  minnesota hip hop
# 2       2                      pop            None               None
# 3       3                  art pop        art rock        baroque pop
# 4       4              atl hip hop             rap   southern hip hop
# ..    ...                      ...             ...                ...
# 95     95  gen z singer-songwriter            None               None
# 96     96                    latin       reggaeton        trap latino
# 97     97     contemporary country         country       country road
# 98     98                    latin       reggaeton        trap latino
# 99     99        argentine hip hop  pop venezolano     trap argentino
#
# [100 rows x 4 columns]

# %%
final_2022_df=a_name.merge(t_name, how='left', on='index')
final_2022_df=final_2022_df.merge(genres, how='left', on='index')
final_2022_df=final_2022_df.merge(audio_fea, how='left', on='index')
final_2022_df
# Out:
#     index      artist_name  year  \
# 0       0          Beyoncé  2022
# 1       1            Lizzo  2022
# 2       2     Harry Styles  2022
# 3       3        Kate Bush  2022
# 4       4           Future  2022
# ..    ...              ...   ...
# 95     95  Stephen Sanchez  2022
# 96     96        Bad Bunny  2022
# 97     97        Jake Owen  2022
# 98     98        Bad Bunny  2022
# 99     99         Bizarrap  2022
#
#                                            track_name  \
# 0                                       BREAK MY SOUL
# 1                                     About Damn Time
# 2                                           As It Was
# 3   Running Up That Hill (A Deal With God) - 2018 ...
# 4                     WAIT FOR U (feat. Drake & Tems)
# ..                                                ...
# 95                                  Until I Found You
# 96                                          Un Ratito
# 97                         Best Thing Since Backroads
# 98                                       La Corriente
# 99              Quevedo: Bzrp Music Sessions, Vol. 52
#
#               primary_genre     sub_genre_1        sub_genre_2  danceability  \
# 0                 dance pop             pop                r&b         0.687
# 1                 dance pop     escape room  minnesota hip hop         0.836
# 2                       pop            None               None         0.520
# 3                   art pop        art rock        baroque pop         0.625
# 4               atl hip hop             rap   southern hip hop         0.463
# ..                      ...             ...                ...           ...
# 95  gen z singer-songwriter            None               None         0.539
# 96                    latin       reggaeton        trap latino         0.787
# 97     contemporary country         country       country road         0.512
# 98                    latin       reggaeton        trap latino         0.663
# 99        argentine hip hop  pop venezolano     trap argentino         0.621
#
#     energy  key  ...  mode  speechiness  acousticness  instrumentalness  \
# 0    0.887    1  ...     0       0.0826        0.0575          0.000002
# 1    0.743   10  ...     0       0.0656        0.0995          0.000000
# 2    0.731    6  ...     0       0.0557        0.3420          0.001010
# 3    0.533   10  ...     0       0.0596        0.6590          0.002660
# 4    0.642    1  ...     1       0.3400        0.3140          0.000000
# ..     ...  ...  ...   ...          ...           ...               ...
# 95   0.508   10  ...     1       0.0288        0.7270          0.000000
# 96   0.546    0  ...     0       0.0532        0.3050          0.000046
# 97   0.841    7  ...     1       0.0309        0.0424          0.000257
# 98   0.786   11  ...     0       0.1950        0.2290          0.000000
# 99   0.782    2  ...     1       0.0440        0.0125          0.033000
#
#     liveness  valence    tempo               track_uri duration_ms  \
# 0     0.2700    0.853  114.941  2KukL7UlQ8TdvpaA7bY3ZJ      278282
# 1     0.3350    0.722  108.966  1PckUlxKqWQs3RlWXVBLw3      191822
# 2     0.3110    0.662  173.930  4LRPiXqCikLlN15c3yImP7      167303
# 3     0.0546    0.139  108.296  29d0nY7TzCoi22XBqDQkiP      300840
# 4     0.0686    0.339   83.389  59nOXPmaKlBfGMDeOVGrIK      189893
# ..       ...      ...      ...                     ...         ...
# 95    0.1740    0.227  101.358  0T5iIrXA4p5GsubkhuBIKV      177720
# 96    0.1220    0.222   93.050  5CzixCxDkRXX9mScCmah8O      176936
# 97    0.1130    0.330  156.077  0R1REdJZIDy7IS3DybdBce      187433
# 98    0.2190    0.579  196.120  1797zYiX4cKosMH836X9Gt      198367
# 99    0.2300    0.550  128.033  2tTmW7RDtMQtBk7m2rYeSw      198938
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               3
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 21 columns]
