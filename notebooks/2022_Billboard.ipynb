# %% [markdown]
# # PERMISSIONS AUTHORIZATION

# %%
import requests
import pandas as pd

# %%
CLIENT_ID = 'c7d16c8600ab433ea5aede2202285c1e'
CLIENT_SECRET = '69b7f20b150845a1ae6427a66f14d780'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
#needs to be updated every hour
headers = {
    'Authorization': 'Bearer BQDmgj4qsXQVUclfpzDkC_-h2HmcIyItUFP5N8mCh7unkViGNqfyem8afSlalNG-UWp8Swl6a3ByG9zfr9rCMoAmuoxAW78iy97W87o0ouRIqYcFlYlpade6Q_ixPGx1NuX3XesH3tXSVCQKcmzDkHxKUEzPWzUAww0dEtGLeIBDyQgdwpf85P-wGS1UpNGm2xE'.format(token=access_token)
}

# %% [markdown]
# # PULLING IN BILLBOARD 1982

# %%
BB_1982_URL="https://api.spotify.com/v1/playlists/1bk6tO6d5oes6n0vhACi5x"
res1982=requests.get(BB_1982_URL, headers=headers)  
res1982
# Out:
# <Response [200]>

# %%
bb1982 = res1982.json()
bb1982.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
bb1982 = res1982.json()['tracks']['items']
bb1982
# Out:
# [{'added_at': '2017-06-29T21:26:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoRxUdrcgbbq1rxJvvhg9'},
#       'href': 'https://api.spotify.com/v1/artists/4BoRxUdrcgbbq1rxJvvhg9',
#       'id': '4BoRxUdrcgbbq1rxJvvhg9',
#       'name': 'Olivia Newton-John',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BoRxUdrcgbbq1rxJvvhg9'}],
#     'available_markets': ['CA', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5wR3bNU1ycW52RrkP4aAXN'},
#     'href': 'https://api.spotify.com/v1/albums/5wR3bNU1ycW52RrkP4aAXN',
#     'id': '5wR3bNU1ycW52RrkP4aAXN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27392ba13060de52ac305208aca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0292ba13060de52ac305208aca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485192ba13060de52ac305208aca',
#       'width': 64}],
#     'name': '20th Century Masters: The Millennium Collection: Best Of Olivia Newton-John',
#     'release_date': '2002-02-05',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5wR3bNU1ycW52RrkP4aAXN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoRxUdrcgbbq1rxJvvhg9'},
#      'href': 'https://api.spotify.com/v1/artists/4BoRxUdrcgbbq1rxJvvhg9',
#      'id': '4BoRxUdrcgbbq1rxJvvhg9',
#      'name': 'Olivia Newton-John',
#      'type': 'artist',
#      'uri': 'spotify:artist:4BoRxUdrcgbbq1rxJvvhg9'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 222400,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC18112103'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3FuL7jThtUAjneBm6puQNk'},
#    'href': 'https://api.spotify.com/v1/tracks/3FuL7jThtUAjneBm6puQNk',
#    'id': '3FuL7jThtUAjneBm6puQNk',
#    'is_local': False,
#    'name': 'Physical',
#    'popularity': 40,
#    'preview_url': 'https://p.scdn.co/mp3-preview/909d57f6ecca663b41e7dbfe51250f874596acc7?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:3FuL7jThtUAjneBm6puQNk'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-12-26T13:42:24Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26bcq2nyj5GB7uRr558iQg'},
#       'href': 'https://api.spotify.com/v1/artists/26bcq2nyj5GB7uRr558iQg',
#       'id': '26bcq2nyj5GB7uRr558iQg',
#       'name': 'Survivor',
#       'type': 'artist',
#       'uri': 'spotify:artist:26bcq2nyj5GB7uRr558iQg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AR',
#      'AT',
#      'BB',
#      'BD',
#      'BE',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BZ',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GR',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'ID',
#      'IE',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KH',
#      'KN',
#      'KR',
#      'KW',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MO',
#      'MT',
#      'MV',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'SA',
#      'SE',
#      'SG',
#      'SM',
#      'SR',
#      'SV',
#      'TH',
#      'TL',
#      'TN',
#      'TT',
#      'TW',
#      'US',
#      'UY',
#      'VC',
#      'VE',
#      'VN'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4PT9VulQaQP6XR1xBI2x1W'},
#     'href': 'https://api.spotify.com/v1/albums/4PT9VulQaQP6XR1xBI2x1W',
#     'id': '4PT9VulQaQP6XR1xBI2x1W',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734e2755e7a96ec5e062c76aac',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024e2755e7a96ec5e062c76aac',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514e2755e7a96ec5e062c76aac',
#       'width': 64}],
#     'name': 'Eye Of The Tiger',
#     'release_date': '1982',
#     'release_date_precision': 'year',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:4PT9VulQaQP6XR1xBI2x1W'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26bcq2nyj5GB7uRr558iQg'},
#      'href': 'https://api.spotify.com/v1/artists/26bcq2nyj5GB7uRr558iQg',
#      'id': '26bcq2nyj5GB7uRr558iQg',
#      'name': 'Survivor',
#      'type': 'artist',
#      'uri': 'spotify:artist:26bcq2nyj5GB7uRr558iQg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AR',
#     'AT',
#     'BB',
#     'BD',
#     'BE',
#     'BH',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BZ',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CW',
#     'CY',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FM',
#     'FR',
#     'GB',
#     'GD',
#     'GR',
#     'GT',
#     'GY',
#     'HK',
#     'HN',
#     'HT',
#     'ID',
#     'IE',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KH',
#     'KN',
#     'KR',
#     'KW',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MO',
#     'MT',
#     'MV',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PK',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'SA',
#     'SG',
#     'SM',
#     'SR',
#     'SV',
#     'TH',
#     'TL',
#     'TN',
#     'TT',
#     'TW',
#     'US',
#     'UY',
#     'VC',
#     'VE',
#     'VN'],
#    'disc_number': 1,
#    'duration_ms': 243773,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USVR19300001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2HHtWyy5CgaQbC7XSoOb0e'},
#    'href': 'https://api.spotify.com/v1/tracks/2HHtWyy5CgaQbC7XSoOb0e',
#    'id': '2HHtWyy5CgaQbC7XSoOb0e',
#    'is_local': False,
#    'name': 'Eye of the Tiger',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/da30b5a3bba5d61dd023f57e484e9dd37d52f5a4?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2HHtWyy5CgaQbC7XSoOb0e'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-17T11:28:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Fmb52lZ6Jv7FMWXXTPO3K'},
#       'href': 'https://api.spotify.com/v1/artists/1Fmb52lZ6Jv7FMWXXTPO3K',
#       'id': '1Fmb52lZ6Jv7FMWXXTPO3K',
#       'name': 'Joan Jett & the Blackhearts',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Fmb52lZ6Jv7FMWXXTPO3K'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/555qwe1qUgLdee80TZ2CQt'},
#     'href': 'https://api.spotify.com/v1/albums/555qwe1qUgLdee80TZ2CQt',
#     'id': '555qwe1qUgLdee80TZ2CQt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733c73b2e0a6aa490736f19751',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023c73b2e0a6aa490736f19751',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513c73b2e0a6aa490736f19751',
#       'width': 64}],
#     'name': "I Love Rock 'N' Roll (Expanded Edition)",
#     'release_date': '1981-11-18',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:555qwe1qUgLdee80TZ2CQt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Fmb52lZ6Jv7FMWXXTPO3K'},
#      'href': 'https://api.spotify.com/v1/artists/1Fmb52lZ6Jv7FMWXXTPO3K',
#      'id': '1Fmb52lZ6Jv7FMWXXTPO3K',
#      'name': 'Joan Jett & the Blackhearts',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Fmb52lZ6Jv7FMWXXTPO3K'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 175173,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USBH18100118'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Cdvbe2G4hZsnhNMKyGrie'},
#    'href': 'https://api.spotify.com/v1/tracks/2Cdvbe2G4hZsnhNMKyGrie',
#    'id': '2Cdvbe2G4hZsnhNMKyGrie',
#    'is_local': False,
#    'name': "I Love Rock 'N Roll",
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/74b95c0214387ed6d0b011902179b6ec10558623?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2Cdvbe2G4hZsnhNMKyGrie'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-29T21:26:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4STHEaNw4mPZ2tzheohgXB'},
#       'href': 'https://api.spotify.com/v1/artists/4STHEaNw4mPZ2tzheohgXB',
#       'id': '4STHEaNw4mPZ2tzheohgXB',
#       'name': 'Paul McCartney',
#       'type': 'artist',
#       'uri': 'spotify:artist:4STHEaNw4mPZ2tzheohgXB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1i7RwnOguDqvZ7myr8VDrh'},
#     'href': 'https://api.spotify.com/v1/albums/1i7RwnOguDqvZ7myr8VDrh',
#     'id': '1i7RwnOguDqvZ7myr8VDrh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a866f3dcb0b55e0f6eee30ac',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a866f3dcb0b55e0f6eee30ac',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a866f3dcb0b55e0f6eee30ac',
#       'width': 64}],
#     'name': 'All The Best',
#     'release_date': '1987-11-02',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:1i7RwnOguDqvZ7myr8VDrh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4STHEaNw4mPZ2tzheohgXB'},
#      'href': 'https://api.spotify.com/v1/artists/4STHEaNw4mPZ2tzheohgXB',
#      'id': '4STHEaNw4mPZ2tzheohgXB',
#      'name': 'Paul McCartney',
#      'type': 'artist',
#      'uri': 'spotify:artist:4STHEaNw4mPZ2tzheohgXB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 220773,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCCS8200460'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1h3bcnnIm72UnemGIfm0iZ'},
#    'href': 'https://api.spotify.com/v1/tracks/1h3bcnnIm72UnemGIfm0iZ',
#    'id': '1h3bcnnIm72UnemGIfm0iZ',
#    'is_local': False,
#    'name': 'Ebony And Ivory',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ede047f954f1894bf9dad3f104e33f3b4f703cb2?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1h3bcnnIm72UnemGIfm0iZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-17T16:46:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69Mj3u4FTUrpyeGNSIaU6F'},
#       'href': 'https://api.spotify.com/v1/artists/69Mj3u4FTUrpyeGNSIaU6F',
#       'id': '69Mj3u4FTUrpyeGNSIaU6F',
#       'name': 'The J. Geils Band',
#       'type': 'artist',
#       'uri': 'spotify:artist:69Mj3u4FTUrpyeGNSIaU6F'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/48joW5905AMbTFLvy8ZWch'},
#     'href': 'https://api.spotify.com/v1/albums/48joW5905AMbTFLvy8ZWch',
#     'id': '48joW5905AMbTFLvy8ZWch',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27338b2429ef948e6ca8d3ab599',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0238b2429ef948e6ca8d3ab599',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485138b2429ef948e6ca8d3ab599',
#       'width': 64}],
#     'name': 'Freeze Frame',
#     'release_date': '1981',
#     'release_date_precision': 'year',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:48joW5905AMbTFLvy8ZWch'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69Mj3u4FTUrpyeGNSIaU6F'},
#      'href': 'https://api.spotify.com/v1/artists/69Mj3u4FTUrpyeGNSIaU6F',
#      'id': '69Mj3u4FTUrpyeGNSIaU6F',
#      'name': 'The J. Geils Band',
#      'type': 'artist',
#      'uri': 'spotify:artist:69Mj3u4FTUrpyeGNSIaU6F'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 216533,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA28100075'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ynmMEK1fkyiZ6Z6F3ThEt'},
#    'href': 'https://api.spotify.com/v1/tracks/1ynmMEK1fkyiZ6Z6F3ThEt',
#    'id': '1ynmMEK1fkyiZ6Z6F3ThEt',
#    'is_local': False,
#    'name': 'Centerfold',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c3d721fdc85bfa980c90a037446238b950182f1f?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1ynmMEK1fkyiZ6Z6F3ThEt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-29T21:26:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aX2dmV8XoHYCOQRxjPESG'},
#       'href': 'https://api.spotify.com/v1/artists/1aX2dmV8XoHYCOQRxjPESG',
#       'id': '1aX2dmV8XoHYCOQRxjPESG',
#       'name': 'The Human League',
#       'type': 'artist',
#       'uri': 'spotify:artist:1aX2dmV8XoHYCOQRxjPESG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7G7TTMHdSQFMmYoFmoVQiY'},
#       'href': 'https://api.spotify.com/v1/artists/7G7TTMHdSQFMmYoFmoVQiY',
#       'id': '7G7TTMHdSQFMmYoFmoVQiY',
#       'name': 'The League Unlimited Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:7G7TTMHdSQFMmYoFmoVQiY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0DhVjSKabBvhgTFPiRYy7F'},
#     'href': 'https://api.spotify.com/v1/albums/0DhVjSKabBvhgTFPiRYy7F',
#     'id': '0DhVjSKabBvhgTFPiRYy7F',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273018394d83431a1db58f2c8fd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02018394d83431a1db58f2c8fd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851018394d83431a1db58f2c8fd',
#       'width': 64}],
#     'name': 'Dare!/Love And Dancing',
#     'release_date': '1981',
#     'release_date_precision': 'year',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:0DhVjSKabBvhgTFPiRYy7F'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aX2dmV8XoHYCOQRxjPESG'},
#      'href': 'https://api.spotify.com/v1/artists/1aX2dmV8XoHYCOQRxjPESG',
#      'id': '1aX2dmV8XoHYCOQRxjPESG',
#      'name': 'The Human League',
#      'type': 'artist',
#      'uri': 'spotify:artist:1aX2dmV8XoHYCOQRxjPESG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 240533,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAA0200924'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7zhtLp2V3lNXdllknAqbKk'},
#    'href': 'https://api.spotify.com/v1/tracks/7zhtLp2V3lNXdllknAqbKk',
#    'id': '7zhtLp2V3lNXdllknAqbKk',
#    'is_local': False,
#    'name': "Don't You Want Me",
#    'popularity': 35,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3391fd5aa04134ac548aa7c3fe92995042d3a4a7?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:7zhtLp2V3lNXdllknAqbKk'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-07-07T20:52:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3lPQ2Fk5JOwGWAF3ORFCqH'},
#       'href': 'https://api.spotify.com/v1/artists/3lPQ2Fk5JOwGWAF3ORFCqH',
#       'id': '3lPQ2Fk5JOwGWAF3ORFCqH',
#       'name': 'John Mellencamp',
#       'type': 'artist',
#       'uri': 'spotify:artist:3lPQ2Fk5JOwGWAF3ORFCqH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4gouGcdQn9OvjX42xnWrF0'},
#     'href': 'https://api.spotify.com/v1/albums/4gouGcdQn9OvjX42xnWrF0',
#     'id': '4gouGcdQn9OvjX42xnWrF0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b1945b44ce8868740f132f8e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b1945b44ce8868740f132f8e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b1945b44ce8868740f132f8e',
#       'width': 64}],
#     'name': 'American Fool',
#     'release_date': '1982',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4gouGcdQn9OvjX42xnWrF0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3lPQ2Fk5JOwGWAF3ORFCqH'},
#      'href': 'https://api.spotify.com/v1/artists/3lPQ2Fk5JOwGWAF3ORFCqH',
#      'id': '3lPQ2Fk5JOwGWAF3ORFCqH',
#      'name': 'John Mellencamp',
#      'type': 'artist',
#      'uri': 'spotify:artist:3lPQ2Fk5JOwGWAF3ORFCqH'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 254493,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJM18200001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/43btz2xjMKpcmjkuRsvxyg'},
#    'href': 'https://api.spotify.com/v1/tracks/43btz2xjMKpcmjkuRsvxyg',
#    'id': '43btz2xjMKpcmjkuRsvxyg',
#    'is_local': False,
#    'name': 'Jack & Diane',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b40dcc374176def7176d834a88b53e54f00f54a4?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:43btz2xjMKpcmjkuRsvxyg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-06-01T13:08:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3lPQ2Fk5JOwGWAF3ORFCqH'},
#       'href': 'https://api.spotify.com/v1/artists/3lPQ2Fk5JOwGWAF3ORFCqH',
#       'id': '3lPQ2Fk5JOwGWAF3ORFCqH',
#       'name': 'John Mellencamp',
#       'type': 'artist',
#       'uri': 'spotify:artist:3lPQ2Fk5JOwGWAF3ORFCqH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4gouGcdQn9OvjX42xnWrF0'},
#     'href': 'https://api.spotify.com/v1/albums/4gouGcdQn9OvjX42xnWrF0',
#     'id': '4gouGcdQn9OvjX42xnWrF0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b1945b44ce8868740f132f8e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b1945b44ce8868740f132f8e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b1945b44ce8868740f132f8e',
#       'width': 64}],
#     'name': 'American Fool',
#     'release_date': '1982',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4gouGcdQn9OvjX42xnWrF0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3lPQ2Fk5JOwGWAF3ORFCqH'},
#      'href': 'https://api.spotify.com/v1/artists/3lPQ2Fk5JOwGWAF3ORFCqH',
#      'id': '3lPQ2Fk5JOwGWAF3ORFCqH',
#      'name': 'John Mellencamp',
#      'type': 'artist',
#      'uri': 'spotify:artist:3lPQ2Fk5JOwGWAF3ORFCqH'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 218960,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJM18200002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/67eX1ovaHyVPUinMHeUtIM'},
#    'href': 'https://api.spotify.com/v1/tracks/67eX1ovaHyVPUinMHeUtIM',
#    'id': '67eX1ovaHyVPUinMHeUtIM',
#    'is_local': False,
#    'name': 'Hurts So Good',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/57bad0259ef461ad8de3e3d6d6fe17424a716cee?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:67eX1ovaHyVPUinMHeUtIM'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-07-07T20:51:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QtGlUje9TIkLrgPZrESuk'},
#       'href': 'https://api.spotify.com/v1/artists/6QtGlUje9TIkLrgPZrESuk',
#       'id': '6QtGlUje9TIkLrgPZrESuk',
#       'name': 'Steve Miller Band',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QtGlUje9TIkLrgPZrESuk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
# ...
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 221000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAC228100002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/35k31HZI4z9PbBOioaI4dZ'},
#    'href': 'https://api.spotify.com/v1/tracks/35k31HZI4z9PbBOioaI4dZ',
#    'id': '35k31HZI4z9PbBOioaI4dZ',
#    'is_local': False,
#    'name': 'Working for the Weekend',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2fc22c6bc30ee8d607ccdcd0b40b2c4bd80c024a?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:35k31HZI4z9PbBOioaI4dZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-29T21:26:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0QXYfxXpKeLlr3hueenIHB'},
#     'href': 'https://api.spotify.com/v1/albums/0QXYfxXpKeLlr3hueenIHB',
#     'id': '0QXYfxXpKeLlr3hueenIHB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b00a6721828724ce38a1e7a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b00a6721828724ce38a1e7a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b00a6721828724ce38a1e7a3',
#       'width': 64}],
#     'name': 'Arthur - The Album [Original Soundtrack]',
#     'release_date': '1981',
#     'release_date_precision': 'year',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:0QXYfxXpKeLlr3hueenIHB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/695W5F2Ih8dYahLdjVOIoH'},
#      'href': 'https://api.spotify.com/v1/artists/695W5F2Ih8dYahLdjVOIoH',
#      'id': '695W5F2Ih8dYahLdjVOIoH',
#      'name': 'Christopher Cross',
#      'type': 'artist',
#      'uri': 'spotify:artist:695W5F2Ih8dYahLdjVOIoH'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 234493,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB10800109'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5fnOrhQ4KgT5irGCjIccGH'},
#    'href': 'https://api.spotify.com/v1/tracks/5fnOrhQ4KgT5irGCjIccGH',
#    'id': '5fnOrhQ4KgT5irGCjIccGH',
#    'is_local': False,
#    'name': "Arthur's Theme (Best That You Can Do)",
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e650123da8c3ca729946e154d537de2dc756d08e?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5fnOrhQ4KgT5irGCjIccGH'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-29T21:26:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tw2Lmn9tTPUv7Gy7mVPI4'},
#       'href': 'https://api.spotify.com/v1/artists/4tw2Lmn9tTPUv7Gy7mVPI4',
#       'id': '4tw2Lmn9tTPUv7Gy7mVPI4',
#       'name': 'Kenny Rogers',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tw2Lmn9tTPUv7Gy7mVPI4'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0AtWFXOdX6hnMIXRfpYoyS'},
#     'href': 'https://api.spotify.com/v1/albums/0AtWFXOdX6hnMIXRfpYoyS',
#     'id': '0AtWFXOdX6hnMIXRfpYoyS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a69390d3fbb3dc68b5f24446',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a69390d3fbb3dc68b5f24446',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a69390d3fbb3dc68b5f24446',
#       'width': 64}],
#     'name': 'A Love Song Collection',
#     'release_date': '2008-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:0AtWFXOdX6hnMIXRfpYoyS'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tw2Lmn9tTPUv7Gy7mVPI4'},
#      'href': 'https://api.spotify.com/v1/artists/4tw2Lmn9tTPUv7Gy7mVPI4',
#      'id': '4tw2Lmn9tTPUv7Gy7mVPI4',
#      'name': 'Kenny Rogers',
#      'type': 'artist',
#      'uri': 'spotify:artist:4tw2Lmn9tTPUv7Gy7mVPI4'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 285026,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCN18100019'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5TSSjhWoGjWJfkfa6lziFJ'},
#    'href': 'https://api.spotify.com/v1/tracks/5TSSjhWoGjWJfkfa6lziFJ',
#    'id': '5TSSjhWoGjWJfkfa6lziFJ',
#    'is_local': False,
#    'name': 'Through The Years - Single Version',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:5TSSjhWoGjWJfkfa6lziFJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-06-01T13:06:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12128872417'},
#    'href': 'https://api.spotify.com/v1/users/12128872417',
#    'id': '12128872417',
#    'type': 'user',
#    'uri': 'spotify:user:12128872417'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7crPfGd2k81ekOoSqQKWWz'},
#       'href': 'https://api.spotify.com/v1/artists/7crPfGd2k81ekOoSqQKWWz',
#       'id': '7crPfGd2k81ekOoSqQKWWz',
#       'name': 'Stevie Nicks',
#       'type': 'artist',
#       'uri': 'spotify:artist:7crPfGd2k81ekOoSqQKWWz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0IomjU2bXFng4LQBYn7Het'},
#     'href': 'https://api.spotify.com/v1/albums/0IomjU2bXFng4LQBYn7Het',
#     'id': '0IomjU2bXFng4LQBYn7Het',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273af14d74d5e308ce2f3ec22f8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02af14d74d5e308ce2f3ec22f8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851af14d74d5e308ce2f3ec22f8',
#       'width': 64}],
#     'name': 'Bella Donna (2016 Remastered)',
#     'release_date': '1981-07-27',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:0IomjU2bXFng4LQBYn7Het'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7crPfGd2k81ekOoSqQKWWz'},
#      'href': 'https://api.spotify.com/v1/artists/7crPfGd2k81ekOoSqQKWWz',
#      'id': '7crPfGd2k81ekOoSqQKWWz',
#      'name': 'Stevie Nicks',
#      'type': 'artist',
#      'uri': 'spotify:artist:7crPfGd2k81ekOoSqQKWWz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 329413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRH11604198'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7L3b6iaVhDVjfo52Hbvh9Z'},
#    'href': 'https://api.spotify.com/v1/tracks/7L3b6iaVhDVjfo52Hbvh9Z',
#    'id': '7L3b6iaVhDVjfo52Hbvh9Z',
#    'is_local': False,
#    'name': 'Edge of Seventeen - 2016 Remaster',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/abb0fd1b61b63ce4023c8f6dd26f5381d1ce5c42?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z'},
#   'video_thumbnail': {'url': None}}]

# %% [raw]
# bb1982.keys()

# %%
my_dict=bb1982
bb1982_df = pd.DataFrame.from_dict(my_dict)
bb1982_df
# Out:
#                 added_at                                           added_by  \
# 0   2017-06-29T21:26:25Z  {'external_urls': {'spotify': 'https://open.sp...
# 1   2017-12-26T13:42:24Z  {'external_urls': {'spotify': 'https://open.sp...
# 2   2020-02-17T11:28:52Z  {'external_urls': {'spotify': 'https://open.sp...
# 3   2017-06-29T21:26:25Z  {'external_urls': {'spotify': 'https://open.sp...
# 4   2020-02-17T16:46:59Z  {'external_urls': {'spotify': 'https://open.sp...
# ..                   ...                                                ...
# 94  2017-06-29T21:26:25Z  {'external_urls': {'spotify': 'https://open.sp...
# 95  2021-06-01T13:06:26Z  {'external_urls': {'spotify': 'https://open.sp...
# 96  2017-06-29T21:26:25Z  {'external_urls': {'spotify': 'https://open.sp...
# 97  2017-06-29T21:26:25Z  {'external_urls': {'spotify': 'https://open.sp...
# 98  2021-06-01T13:06:06Z  {'external_urls': {'spotify': 'https://open.sp...
#
#     is_local primary_color                                              track  \
# 0      False          None  {'album': {'album_type': 'compilation', 'artis...
# 1      False          None  {'album': {'album_type': 'album', 'artists': [...
# 2      False          None  {'album': {'album_type': 'album', 'artists': [...
# 3      False          None  {'album': {'album_type': 'compilation', 'artis...
# 4      False          None  {'album': {'album_type': 'album', 'artists': [...
# ..       ...           ...                                                ...
# 94     False          None  {'album': {'album_type': 'compilation', 'artis...
# 95     False          None  {'album': {'album_type': 'album', 'artists': [...
# 96     False          None  {'album': {'album_type': 'compilation', 'artis...
# 97     False          None  {'album': {'album_type': 'compilation', 'artis...
# 98     False          None  {'album': {'album_type': 'album', 'artists': [...
#
#    video_thumbnail
# 0    {'url': None}
# 1    {'url': None}
# 2    {'url': None}
# 3    {'url': None}
# 4    {'url': None}
# ..             ...
# 94   {'url': None}
# 95   {'url': None}
# 96   {'url': None}
# 97   {'url': None}
# 98   {'url': None}
#
# [99 rows x 6 columns]

# %%
import spotipy
sp = spotipy.Spotify()
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/embed/playlist/1bk6tO6d5oes6n0vhACi5x?utm_source=generator"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
    for track in sp.playlist_tracks(playlist_URI)["items"]:
        #URI
        track_uri = track["track"]["uri"]

        #Track name
        track_name = track["track"]["name"]

        #Main Artist
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)

        #Name, popularity, genre
        artist_name = track["track"]["artists"][0]["name"]
        artist_pop = artist_info["popularity"]
        artist_genres = artist_info["genres"]

        #Album
        album = track["track"]["album"]["name"]

        #Popularity of the track
        track_pop = track["track"]["popularity"]
        
        result = track_name, track_uri,artist_uri, artist_info, artist_name, artist_pop, artist_genres,album, track_pop

    result
# Out:
# ('Edge of Seventeen - 2016 Remaster',
#  'spotify:track:7L3b6iaVhDVjfo52Hbvh9Z',
#  'spotify:artist:7crPfGd2k81ekOoSqQKWWz',
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7crPfGd2k81ekOoSqQKWWz'},
#   'followers': {'href': None, 'total': 956574},
#   'genres': ['album rock',
#    'heartland rock',
#    'mellow gold',
#    'rock',
#    'soft rock'],
#   'href': 'https://api.spotify.com/v1/artists/7crPfGd2k81ekOoSqQKWWz',
#   'id': '7crPfGd2k81ekOoSqQKWWz',
#   'images': [{'height': 1500,
#     'url': 'https://i.scdn.co/image/de290cc5eb07bc3b2921008725d70d9d1573246c',
#     'width': 1000},
#    {'height': 960,
#     'url': 'https://i.scdn.co/image/44ff31fead2043c7730330fd4308e9325a0aef83',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/5357d46d3c5ab76b95a2e50da8f24cd69fc66633',
#     'width': 200},
#    {'height': 96,
#     'url': 'https://i.scdn.co/image/d1d4f49dda40c9b071e734f729d82e1108f43230',
#     'width': 64}],
#   'name': 'Stevie Nicks',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:7crPfGd2k81ekOoSqQKWWz'},
#  'Stevie Nicks',
#  65,
#  ['album rock', 'heartland rock', 'mellow gold', 'rock', 'soft rock'],
#  'Bella Donna (2016 Remastered)',
#  70)

# %%
artist_images = artist_info["images"]
# Out:
# tuple

# %%
dataList = list(result)
type(dataList)
# Out:
# list

# %%
df = pd.DataFrame(
    dataList, columns=['track_name', 'track_uri','artist_uri', 'artist_info', 'artist_name', 'artist_pop', 'artist_genres','album', 'track_pop'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df = pd.DataFrame(
#       2     dataList, columns=['track_name', 'track_uri','artist_uri', 'artist_info', 'artist_name', 'artist_pop', 'artist_genres','album', 'track_pop'])
#       3 print(df)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:737, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     729         mgr = arrays_to_mgr(
#     730             arrays,
#     731             columns,
#    (...)
#     734             typ=manager,
#     735         )
#     736     else:
# --> 737         mgr = ndarray_to_mgr(
#     738             data,
#     739             index,
#     740             columns,
#     741             dtype=dtype,
#     742             copy=copy,
#     743             typ=manager,
#     744         )
#     745 else:
#     746     mgr = dict_to_mgr(
#     747         {},
#     748         index,
#    (...)
#     751         typ=manager,
#     752     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:351, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
#     347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
# --> 351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#     355     if issubclass(values.dtype.type, str):
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:422, in _check_values_indices_shape_match(values, index, columns)
#     420 passed = values.shape
#     421 implied = (len(index), len(columns))
# --> 422 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (9, 1), indices imply (9, 9)

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        artist_uri = track["track"]["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)
        artist_name = track["track"]["artists"][0]["name"]
        artist_pop = artist_info["popularity"]
        artist_genres = artist_info["genres"]
        album = track["track"]["album"]["name"]
        track_pop = track["track"]["popularity"]
        track_uri = track["track"]["uri"]
        track_name = track["track"]["name"]
        result = track_name, track_uri,artist_uri, artist_info, artist_name, artist_pop, artist_genres,album, track_pop, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


the_stuff = get_tracks()

# %%
the_stuff[0]

# %%
the_stuff[0][3]['name']

# %%
def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(playlist_link)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_uri = track["track"]["uri"]
        track_name = track["track"]["name"]
        result = track_name, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks


the_stuff_2 = get_tracks()

# %%
the_stuff

# %%
get_tracks()

# %%
df= pd.DataFrame(the_suff, columns=['track_uri','track_name', 'result',])
